# %%
import pandas as pd
df = pd.read_csv("new_complaints.csv")
df_copy = df.copy()
df = df[["Consumer complaint narrative", "Product"]]

# %%
df = df.dropna()

# %%
# df

# %%
sents = df["Consumer complaint narrative"].iloc[:50].tolist()

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
# sents

# %%
words = [word_tokenize(x) for x in sents]

# %%
words
# Out:
# [['When',
#   'my',
#   'loan',
#   'was',
#   'switched',
#   'over',
#   'to',
#   'Navient',
#   'i',
#   'was',
#   'never',
#   'told',
#   'that',
#   'i',
#   'had',
#   'a',
#   'deliquint',
#   'balance',
#   'because',
#   'with',
#   'XXXX',
#   'i',
#   'did',
#   'not',
#   '.',
#   'When',
#   'going',
#   'to',
#   'purchase',
#   'a',
#   'vehicle',
#   'i',
#   'discovered',
#   'my',
#   'credit',
#   'score',
#   'had',
#   'been',
#   'dropped',
#   'from',
#   'the',
#   'XXXX',
#   'into',
#   'the',
#   'XXXX',
#   '.',
#   'I',
#   'have',
#   'been',
#   'faithful',
#   'at',
#   'paying',
#   'my',
#   'student',
#   'loan',
#   '.',
#   'I',
#   'was',
#   'told',
#   'that',
#   'Navient',
#   'was',
#   'the',
#   'company',
#   'i',
#   'had',
#   'delinquency',
#   'with',
#   '.',
#   'I',
#   'contacted',
#   'Navient',
#   'to',
#   'resolve',
#   'this',
#   'issue',
#   'you',
#   'and',
#   'kept',
#   'being',
#   'told',
#   'to',
#   'just',
#   'contact',
#   'the',
#   'credit',
#   'bureaus',
#   'and',
#   'expalin',
#   'the',
#   'situation',
#   'and',
#   'maybe',
#   'they',
#   'could',
#   'help',
#   'me',
#   '.',
#   'I',
#   'was',
#   'so',
#   'angry',
#   'that',
#   'i',
#   'just',
#   'hurried',
#   'and',
#   'paid',
#   'the',
#   'balance',
#   'off',
#   'and',
#   'then',
#   'after',
#   'tried',
#   'to',
#   'dispute',
#   'the',
#   'delinquency',
#   'with',
#   'the',
#   'credit',
#   'bureaus',
#   '.',
#   'I',
#   'have',
#   'had',
#   'so',
#   'much',
#   'trouble',
#   'bringing',
#   'my',
#   'credit',
#   'score',
#   'back',
#   'up',
#   '.'],
#  ['I',
#   'tried',
#   'to',
#   'sign',
#   'up',
#   'for',
#   'a',
#   'spending',
#   'monitoring',
#   'program',
#   'and',
#   'Capital',
#   'One',
#   'will',
#   'not',
#   'let',
#   'me',
#   'access',
#   'my',
#   'account',
#   'through',
#   'them'],
#  ['My',
#   'mortgage',
#   'is',
#   'with',
#   'BB',
#   '&',
#   'T',
#   'Bank',
#   ',',
#   'recently',
#   'I',
#   'have',
#   'been',
#   'investigating',
#   'ways',
#   'to',
#   'pay',
#   'down',
#   'my',
#   'mortgage',
#   'faster',
#   'and',
#   'I',
#   'came',
#   'across',
#   'Biweekly',
#   'Mortgage',
#   'Calculator',
#   'on',
#   'BB',
#   '&',
#   'T',
#   "'s",
#   'website',
#   '.',
#   'It',
#   "'s",
#   'a',
#   'nice',
#   ',',
#   'easy',
#   'to',
#   'use',
#   'calculator',
#   'that',
#   'you',
#   'plug',
#   'in',
#   'your',
#   'interest',
#   'rate',
#   ',',
#   'mortgage',
#   'amount',
#   ',',
#   'mortgage',
#   'term',
#   ',',
#   'and',
#   'payment',
#   'type',
#   'and',
#   'it',
#   'calculates',
#   'your',
#   'accelerated',
#   'bi-weekly',
#   'payment',
#   'for',
#   'you',
#   'and',
#   'shows',
#   'you',
#   'how',
#   'much',
#   'quicker',
#   'you',
#   'can',
#   'pay',
#   'down',
#   'your',
#   'loan',
#   '.',
#   'Ours',
#   'figured',
#   'out',
#   'to',
#   'pay',
#   'off',
#   'a',
#   '30',
#   'year',
#   'mortgage',
#   'in',
#   '26.4',
#   'years',
#   '...',
#   'quite',
#   'a',
#   'savings',
#   '!',
#   'I',
#   'called',
#   'BB',
#   '&',
#   'T',
#   "'s",
#   'customer',
#   'service',
#   'number',
#   'to',
#   'inquire',
#   'how',
#   'I',
#   'get',
#   'set',
#   'up',
#   'on',
#   'this',
#   'payment',
#   'plan',
#   '.',
#   'I',
#   'was',
#   'told',
#   'they',
#   'do',
#   'not',
#   'offer',
#   'that',
#   'type',
#   'of',
#   'payment',
#   'plan',
#   ',',
#   'but',
#   'I',
#   'could',
#   'send',
#   'in',
#   'my',
#   'payments',
#   'bi-weekly',
#   'but',
#   'it',
#   'would',
#   'not',
#   'be',
#   'applied',
#   'until',
#   'the',
#   'full',
#   'amount',
#   'was',
#   'received',
#   '.',
#   '(',
#   'the',
#   'money',
#   'would',
#   'sit',
#   'in',
#   'a',
#   '``',
#   'holding',
#   'account',
#   '``',
#   'until',
#   'the',
#   'full',
#   'payment',
#   'amount',
#   'was',
#   'collected',
#   ')',
#   '.',
#   'I',
#   'ended',
#   'up',
#   'calling',
#   'back',
#   'a',
#   'few',
#   'days',
#   'later',
#   'thinking',
#   'the',
#   'rep',
#   'I',
#   'was',
#   'talking',
#   'to',
#   'did',
#   "n't",
#   'understand',
#   'what',
#   'I',
#   'wanted',
#   'to',
#   'do',
#   'or',
#   'was',
#   'not',
#   'knowledgeable',
#   'of',
#   'this',
#   'program',
#   '.',
#   'I',
#   'got',
#   'the',
#   'SAME',
#   'ANSWER',
#   '!',
#   'I',
#   'then',
#   'asked',
#   'for',
#   'the',
#   'corporate',
#   'BB',
#   '&',
#   'T',
#   'office',
#   'number',
#   'where',
#   'I',
#   'could',
#   'speak',
#   'to',
#   'someone',
#   'that',
#   'was',
#   'knowledgeable',
#   'of',
#   'this',
#   'product',
#   '.',
#   'After',
#   '3',
#   'days',
#   'I',
#   'received',
#   'a',
#   'phone',
#   'call',
#   'back',
#   'from',
#   'a',
#   'corporate',
#   'manager',
#   'stating',
#   'they',
#   'do',
#   'not',
#   'offer',
#   'this',
#   'product',
#   ',',
#   'and',
#   'they',
#   'were',
#   '``',
#   'checking',
#   'into',
#   'why',
#   'this',
#   'is',
#   'on',
#   'their',
#   'website',
#   '``',
#   '.',
#   'She',
#   'stated',
#   'they',
#   'do',
#   'have',
#   'a',
#   'few',
#   'customers',
#   'that',
#   'make',
#   'bi-weekly',
#   'payments',
#   ',',
#   'but',
#   'they',
#   'no',
#   'longer',
#   'offer',
#   'this',
#   'service',
#   '.',
#   'I',
#   'do',
#   "n't",
#   'understand',
#   'how',
#   'they',
#   'can',
#   'have',
#   'this',
#   'active',
#   'link',
#   'on',
#   'their',
#   'website',
#   'under',
#   'their',
#   'Financial',
#   'Planning',
#   'Center',
#   'tab',
#   'to',
#   'mislead',
#   'customers',
#   'when',
#   'all',
#   'they',
#   'say',
#   'is',
#   '``',
#   'I',
#   "'m",
#   'sorry',
#   ',',
#   'I',
#   'know',
#   'you',
#   "'re",
#   'upset',
#   'about',
#   'this',
#   '``',
#   'Sounds',
#   'like',
#   'false',
#   'advertising',
#   'to',
#   'me',
#   '!',
#   'https',
#   ':',
#   '//www.bbt.com/XXXX'],
#  ['The',
#   'entire',
#   'lending',
#   'experience',
#   'with',
#   'Citizens',
#   'Bank',
#   'was',
#   'terrible',
#   '.',
#   'The',
#   'lender',
#   'kept',
#   'pushing',
#   'a',
#   'XXXX',
#   'ARM',
#   ',',
#   'which',
#   'we',
#   'had',
#   'considered',
#   'initially',
#   'but',
#   'decided',
#   'to',
#   'go',
#   'with',
#   'a',
#   '30yr',
#   'fixed',
#   '.',
#   'When',
#   'we',
#   'received',
#   'the',
#   'closing',
#   'disclosure',
#   ',',
#   'it',
#   'was',
#   'a',
#   'XXXX',
#   'ARM',
#   ',',
#   'we',
#   'immediately',
#   'requested',
#   'that',
#   'it',
#   'be',
#   'corrected',
#   'to',
#   'the',
#   '30yr',
#   'fixed',
#   'we',
#   'decided',
#   'upon',
#   'but',
#   'they',
#   'kept',
#   'delaying',
#   'and',
#   'saying',
#   'it',
#   'was',
#   'changed',
#   'but',
#   'would',
#   "n't",
#   'send',
#   'it',
#   'to',
#   'us',
#   '.',
#   'They',
#   'waited',
#   'until',
#   'the',
#   'next',
#   'day',
#   'and',
#   'then',
#   'tried',
#   'to',
#   'convince',
#   'us',
#   'to',
#   'waive',
#   'our',
#   'rights',
#   'so',
#   'it',
#   'would',
#   "n't",
#   'push',
#   'the',
#   'closing',
#   'date',
#   'due',
#   'to',
#   'the',
#   '3',
#   'day',
#   'clock',
#   'reset',
#   '.',
#   'This',
#   'seemed',
#   'very',
#   'intentional',
#   ',',
#   'like',
#   'it',
#   'was',
#   'something',
#   'they',
#   'often',
#   'do',
#   ',',
#   'because',
#   'they',
#   'sent',
#   'us',
#   'an',
#   'email',
#   'instructing',
#   'us',
#   'to',
#   'draft',
#   'a',
#   'letter',
#   ':',
#   '--',
#   '--',
#   'From',
#   'the',
#   'loan',
#   'officer',
#   ':',
#   'I',
#   'have',
#   'outlined',
#   'the',
#   'basis',
#   'of',
#   'the',
#   'letter',
#   'in',
#   'this',
#   'email',
#   '.',
#   'Please',
#   'elaborate',
#   'on',
#   'why',
#   'you',
#   'wanted',
#   'the',
#   'product',
#   'changed',
#   'and',
#   'make',
#   'sure',
#   'to',
#   'include',
#   'your',
#   'contact',
#   'information',
#   'at',
#   'the',
#   'bottom',
#   'as',
#   'they',
#   'will',
#   'need',
#   'this.',
#   "''",
#   'To',
#   'Whom',
#   'it',
#   'may',
#   'concern',
#   ',',
#   'This',
#   'letter',
#   'is',
#   'to',
#   'waive',
#   'my',
#   'right',
#   'to',
#   'review',
#   'the',
#   'new',
#   'Closing',
#   'Disclosure',
#   '3',
#   'business',
#   'days',
#   'prior',
#   'to',
#   'closing',
#   '.',
#   'I',
#   'must',
#   'close',
#   'on',
#   'the',
#   'property',
#   'at',
#   '(',
#   'property',
#   'address',
#   ')',
#   'or',
#   'I',
#   'face',
#   'financial',
#   'hardship',
#   'in',
#   'the',
#   'form',
#   'of',
#   'losing',
#   'my',
#   'Earnest',
#   'Money',
#   'Deposit',
#   'and',
#   'property',
#   'falling',
#   'through',
#   '.',
#   'I',
#   'must',
#   'close',
#   'on',
#   'this',
#   'property',
#   'on',
#   'XXXX',
#   '.',
#   'There',
#   'is',
#   'substantial',
#   'expense',
#   'associated',
#   'with',
#   'my',
#   'drive',
#   'and',
#   'move',
#   'to',
#   '(',
#   'property',
#   'address',
#   ')',
#   'and',
#   'require',
#   'this',
#   'property',
#   'so',
#   'I',
#   'may',
#   'begin',
#   '(',
#   'new',
#   'job',
#   ')',
#   'on',
#   'time',
#   '.',
#   'In',
#   'addition',
#   'this',
#   'letter',
#   'is',
#   'to',
#   'address',
#   'the',
#   'change',
#   'in',
#   'rate',
#   'and',
#   'product',
#   '.',
#   'This',
#   'was',
#   'done',
#   'at',
#   'my',
#   'request',
#   ',',
#   'I',
#   'requested',
#   'a',
#   '30',
#   'year',
#   'fixed',
#   'rate',
#   'loan',
#   'that',
#   'increased',
#   'my',
#   'rate',
#   'to',
#   '(',
#   '%',
#   ')',
#   'and',
#   'increased',
#   'my',
#   'APR',
#   '.',
#   'I',
#   'decided',
#   'that',
#   'the',
#   '30',
#   'Year',
#   'Fixed',
#   'was',
#   'a',
#   'safe',
#   'option',
#   'to',
#   'avoid',
#   'the',
#   'market',
#   'causing',
#   'my',
#   'ARM',
#   'rate',
#   'to',
#   'increase',
#   '.',
#   'I',
#   'felt',
#   'as',
#   'though',
#   'the',
#   'difference',
#   'in',
#   'payment',
#   'monthly',
#   'was',
#   'worth',
#   'the',
#   'security',
#   'of',
#   'having',
#   'a',
#   'fixed',
#   'rate',
#   'and',
#   'knowing',
#   'the',
#   'rate',
#   'could',
#   'not',
#   'increase',
#   '.',
#   'I',
#   'am',
#   'fully',
#   'aware',
#   'that',
#   'the',
#   'rate',
#   'and',
#   'APR',
#   'increased',
#   'and',
#   'am',
#   'fully',
#   'aware',
#   'of',
#   'the',
#   'difference',
#   'in',
#   'monthly',
#   'payment',
#   'however',
#   'I',
#   'still',
#   'wish',
#   'to',
#   'go',
#   'with',
#   'the',
#   '30',
#   'Year',
#   'Fixed',
#   'and',
#   'need',
#   'to',
#   'close',
#   'on',
#   'XXXX',
#   '.',
#   'My',
#   'contact',
#   'information',
#   'is',
#   'below',
#   'and',
#   'should',
#   'anyone',
#   'have',
#   'any',
#   'questions',
#   'please',
#   'do',
#   'not',
#   'hesitate',
#   'to',
#   'reach',
#   'out',
#   'to',
#   'me',
#   '.',
#   'I',
#   'look',
#   'forward',
#   'to',
#   'closing',
#   'my',
#   'loan.',
#   '``',
#   'Please',
#   'make',
#   'sure',
#   'to',
#   'physically',
#   'sign',
#   'and',
#   'date',
#   'this',
#   'at',
#   'the',
#   'bottom',
#   'and',
#   'send',
#   'back',
#   'so',
#   'we',
#   'can',
#   'close',
#   'on',
#   'time',
#   '.',
#   'Thanks',
#   '--',
#   '--',
#   'We',
#   'responded',
#   'with',
#   'this',
#   ':',
#   '``',
#   'We',
#   'do',
#   "n't",
#   'feel',
#   'comfortable',
#   'moving',
#   'forward',
#   'by',
#   'waving',
#   'our',
#   'rights',
#   'to',
#   'review',
#   'a',
#   'closing',
#   'disclosure',
#   '.',
#   'We',
#   'would',
#   'like',
#   'to',
#   'receive',
#   'the',
#   'corrected',
#   'closing',
#   'disclosure',
#   'for',
#   'the',
#   '30yr',
#   'fixed',
#   'including',
#   'the',
#   'corrected',
#   'deposit',
#   'amount',
#   'and',
#   'we',
#   'understand',
#   'that',
#   'this',
#   'will',
#   'reset',
#   'the',
#   'clock',
#   '.',
#   'We',
#   'would',
#   'really',
#   'appreciate',
#   'it',
#   'if',
#   'this',
#   'could',
#   'be',
#   'done',
#   'tonight',
#   'since',
#   'our',
#   'closing',
#   'date',
#   'has',
#   'already',
#   'been',
#   'pushed',
#   'more',
#   'than',
#   'expected.',
#   '``',
#   'They',
#   'finally',
#   'sent',
#   'us',
#   'the',
#   'correct',
#   'closing',
#   'disclosure',
#   '.',
#   'On',
#   'several',
#   'occasions',
#   'we',
#   'asked',
#   'about',
#   'having',
#   'to',
#   'open',
#   'a',
#   'checking',
#   'account',
#   'and',
#   'were',
#   'told',
#   'we',
#   'would',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'later',
#   'if',
#   'we',
#   'desired',
#   'but',
#   'there',
#   'would',
#   'be',
#   'no',
#   'discount',
#   'for',
#   'having',
#   'an',
#   'account',
#   '.',
#   'We',
#   'decided',
#   'we',
#   'did',
#   "n't",
#   'need',
#   'one',
#   ',',
#   'during',
#   'closing',
#   'we',
#   'set',
#   'up',
#   'our',
#   'mortgage',
#   'payments',
#   'to',
#   'come',
#   'directly',
#   'out',
#   'of',
#   'our',
#   'primary',
#   'bank',
#   'account',
#   'with',
#   'another',
#   'institution',
#   '.',
#   'On',
#   'XXXX',
#   'XXXX',
#   'we',
#   'received',
#   'an',
#   'email',
#   'stating',
#   'a',
#   'form',
#   'was',
#   'to',
#   'be',
#   'signed',
#   'that',
#   'was',
#   'forgotten',
#   'during',
#   'closing',
#   '.',
#   'The',
#   'form',
#   'was',
#   'dated',
#   'XXXX',
#   'XXXX',
#   'and',
#   'was',
#   'an',
#   'ACH',
#   'for',
#   'a',
#   'direct',
#   'debit',
#   'of',
#   'the',
#   'mortgage',
#   'payment',
#   'from',
#   'a',
#   'bank',
#   'account',
#   'with',
#   'Citizens',
#   'Bank',
#   '.',
#   'We',
#   'said',
#   'we',
#   'were',
#   'not',
#   'going',
#   'to',
#   'sign',
#   'it',
#   ',',
#   'we',
#   'had',
#   'already',
#   'set',
#   'up',
#   'payments',
#   'from',
#   'our',
#   'bank',
#   'and',
#   'signed',
#   'an',
#   'ACH',
#   'form',
#   ',',
#   'and',
#   'this',
#   'form',
#   'was',
#   'not',
#   '``',
#   'forgotten',
#   '``',
#   'at',
#   'closing',
#   '.',
#   'The',
#   'form',
#   'had',
#   'an',
#   'account',
#   'number',
#   'on',
#   'it',
#   ',',
#   'we',
#   'asked',
#   'how',
#   'they',
#   'could',
#   'have',
#   'an',
#   'account',
#   'number',
#   'if',
#   'we',
#   'do',
#   "n't",
#   'even',
#   'have',
#   'a',
#   'Citizens',
#   'bank',
#   'account',
#   '...',
#   '.It',
#   'turns',
#   'out',
#   'they',
#   'opened',
#   'checking',
#   ',',
#   'savings',
#   'and',
#   'credit',
#   'line',
#   'accounts',
#   'in',
#   'my',
#   'husband',
#   "'s",
#   'name',
#   'without',
#   'our',
#   'authorization',
#   ',',
#   'they',
#   'even',
#   'charged',
#   'the',
#   'credit',
#   'line',
#   'for',
#   'the',
#   'opening',
#   'deposit',
#   'into',
#   'the',
#   'checking',
#   'account',
#   'all',
#   'without',
#   'any',
#   'authorization',
#   'or',
#   'signatures',
#   '!',
#   'We',
#   'are',
#   'still',
#   'fighting',
#   'to',
#   'get',
#   'them',
#   'properly',
#   'closed',
#   '.'],
#  ['My',
#   'credit',
#   'score',
#   'has',
#   'gone',
#   'down',
#   'XXXX',
#   'points',
#   'in',
#   'the',
#   'last',
#   'month',
#   '-',
#   'from',
#   'the',
#   'XXXX',
#   "'s",
#   'to',
#   'the',
#   'XXXX',
#   "'s",
#   '.',
#   'I',
#   'requested',
#   'and',
#   'reviewed',
#   'reports',
#   'from',
#   'all',
#   'XXXX',
#   'credit',
#   'reporting',
#   'agencies',
#   'and',
#   'I',
#   'can',
#   'not',
#   'find',
#   'a',
#   'significant',
#   'reason',
#   'for',
#   'the',
#   'significant',
#   'decrease',
#   'in',
#   'my',
#   'score',
#   '.',
#   'Please',
#   'help',
#   'me',
#   '.'],
#  ['I',
#   'few',
#   'months',
#   'back',
#   'I',
#   'contacted',
#   'XXXX',
#   'in',
#   'regards',
#   'to',
#   'fraudulent',
#   'accounts',
#   'one',
#   'being',
#   'XXXX',
#   'XXXX',
#   '.',
#   'I',
#   'sent',
#   'in',
#   'the',
#   'necessary',
#   'documents',
#   'affidavit',
#   ',',
#   'police',
#   'report',
#   '.',
#   'They',
#   'removed',
#   'the',
#   'account',
#   'now',
#   'the',
#   'account',
#   'has',
#   'appeared',
#   'back',
#   'on',
#   'my',
#   'report',
#   'under',
#   'XXXX',
#   'XXXX',
#   'and',
#   'XXXX',
#   'allowed',
#   'that',
#   '.',
#   'Dropping',
#   'my',
#   'score',
#   'tremendously'],
#  ['I',
#   '``',
#   'm',
#   'a',
#   'victim',
#   'of',
#   'fraud',
#   'and',
#   'I',
#   'have',
#   'a',
#   'file',
#   'with',
#   'the',
#   'Federal',
#   'Trade',
#   'Commission',
#   '.',
#   'While',
#   'preparing',
#   'to',
#   'check',
#   'my',
#   'credit',
#   'for',
#   'incorrect',
#   'information',
#   ',',
#   'I',
#   'have',
#   'noticed',
#   'there',
#   'are',
#   'six',
#   'inquires',
#   'that',
#   'I',
#   'have',
#   'no',
#   'knowledge',
#   'of',
#   'nor',
#   'do',
#   'I',
#   'have',
#   'or',
#   'ever',
#   'had',
#   'any',
#   'accounts',
#   'opened',
#   'with',
#   'the',
#   'companies',
#   ',',
#   'please',
#   'will',
#   'you',
#   'help',
#   'me',
#   'in',
#   'solving',
#   'these',
#   'issues',
#   '?',
#   '1.XXXX/XXXX',
#   '...',
#   '.National',
#   'Credit',
#   'Cards/Airlines',
#   '4.XXXX',
#   'XXXX',
#   '...',
#   '.',
#   'inquiry',
#   'date',
#   ':',
#   'XXXX',
#   'inquiry',
#   'date',
#   ':',
#   'XXXX',
#   '2.XXXX/XXXX',
#   '...',
#   '.',
#   '5',
#   '.',
#   'XXXX',
#   'XXXX',
#   '...',
#   '.',
#   'inquiry',
#   'date',
#   ':',
#   'XX/XX/XXXX',
#   'inquiry',
#   'date',
#   ':',
#   'XXXX',
#   '3.XXXX',
#   '...',
#   '.',
#   '6',
#   '.',
#   'XXXX',
#   'XXXX',
#   '...',
#   'inquiry',
#   'date',
#   ':',
#   'XX/XX/XXXX',
#   'inquiry',
#   'date',
#   ':',
#   'XX/XX/XXXX'],
#  ['I',
#   'have',
#   'been',
#   'disputing',
#   'a',
#   'Bankruptcy',
#   'on',
#   'my',
#   'credit',
#   'report',
#   'i',
#   'have',
#   'written',
#   'to',
#   'the',
#   'bureau',
#   'for',
#   'the',
#   'past',
#   '3',
#   'years',
#   'i',
#   'call',
#   'them',
#   'on',
#   'the',
#   'phone',
#   '2',
#   'dozen',
#   'times',
#   'i',
#   'wrote',
#   'to',
#   'the',
#   'XXXX',
#   'district',
#   'Court',
#   'about',
#   'a',
#   'Bankruptcy',
#   'that',
#   'both',
#   'Experian',
#   'and',
#   'XXXX',
#   'have',
#   'been',
#   'reporting',
#   'in',
#   'Accurately',
#   'on',
#   'my',
#   'Bureau',
#   'the',
#   'court',
#   'sent',
#   'me',
#   'a',
#   'letter',
#   'indicating',
#   'that',
#   'they',
#   'DID',
#   'NOT',
#   'AND',
#   'DO',
#   'NOT',
#   'report',
#   'to',
#   'any',
#   'Credit',
#   'Bureaus',
#   'i',
#   'sent',
#   'these',
#   'letters',
#   'to',
#   'the',
#   'Bureaus',
#   'and',
#   'they',
#   'say',
#   'that',
#   'they',
#   'have',
#   'verify',
#   'this',
#   'as',
#   'a',
#   'accurate',
#   'item',
#   'reported',
#   'by',
#   'the',
#   'court',
#   'so',
#   'I',
#   'went',
#   'to',
#   'the',
#   'XXXX',
#   'District',
#   'court',
#   'with',
#   'my',
#   'ID',
#   'and',
#   'they',
#   'said',
#   'to',
#   'me',
#   'that',
#   'we',
#   'do',
#   "n't",
#   'have',
#   'a',
#   'BANKRUPTCY',
#   'in',
#   'my',
#   'name',
#   'they',
#   'then',
#   'told',
#   'me',
#   'that',
#   'the',
#   'Bureau',
#   'gets',
#   'this',
#   'information',
#   'from',
#   'XXXX',
#   'XXXX',
#   'i',
#   'contacted',
#   'them',
#   'by',
#   'phone',
#   'and',
#   'in',
#   'writing',
#   'they',
#   'have',
#   'never',
#   'responded',
#   'by',
#   'phone',
#   'or',
#   'mail',
#   'so',
#   'i',
#   'sent',
#   'a',
#   'letter',
#   'to',
#   'the',
#   'Bureau',
#   'explaining',
#   'that',
#   'they',
#   'show',
#   'me',
#   'their',
#   'Method',
#   'of',
#   'Verification',
#   'they',
#   'responded',
#   'that',
#   'the',
#   'info',
#   'was',
#   'verified',
#   'by',
#   'XXXX',
#   'XXXX',
#   'i',
#   'asked',
#   'them',
#   'then',
#   'why',
#   'is',
#   "n't",
#   'XXXX',
#   'XXXX',
#   'showing',
#   'on',
#   'my',
#   'credit',
#   'report',
#   'they',
#   'said',
#   'that',
#   'i',
#   'should',
#   'contact',
#   'them',
#   'bottom',
#   'line',
#   'is',
#   'they',
#   'do',
#   "n't",
#   'give',
#   'a',
#   'XXXX',
#   'about',
#   'me',
#   'and',
#   'my',
#   'credit',
#   'and',
#   'how',
#   'this',
#   'effects',
#   'my',
#   'life',
#   'so',
#   'i',
#   'have',
#   'spoken',
#   'with',
#   'a',
#   'attorney',
#   'he',
#   'said',
#   'that',
#   'i',
#   'should',
#   'fit',
#   'a',
#   'complaint',
#   'with',
#   'you',
#   'so',
#   'i',
#   'am',
#   'complain',
#   'that',
#   'these',
#   'Bureaus',
#   'are',
#   'ignoring',
#   'the',
#   'Fair',
#   'Credit',
#   'act',
#   'and',
#   'have',
#   'no',
#   'fear',
#   'of',
#   'your',
#   'organization',
#   'the',
#   'attorney',
#   'general',
#   'or',
#   'the',
#   'federal',
#   'Trade',
#   'commission',
#   'so',
#   'I',
#   'am',
#   'asking',
#   'for',
#   'your',
#   'help',
#   'in',
#   'this',
#   'matter',
#   'if',
#   'they',
#   'have',
#   'verified',
#   'this',
#   'then',
#   'i',
#   'have',
#   'a',
#   'right',
#   'to',
#   'know',
#   'who',
#   'they',
#   'verified',
#   'this',
#   'information',
#   'with',
#   'NAME',
#   'EMAIL',
#   'PHONE',
#   'NUMBER',
#   'etc',
#   '.'],
#  ['Today',
#   'I',
#   'received',
#   'a',
#   'phone',
#   'call',
#   'from',
#   'a',
#   'number',
#   'listed',
#   'as',
#   '``',
#   'XXXX',
#   '``',
#   'at',
#   'XXXX',
#   'XXXX',
#   'on',
#   'XXXX/XXXX/XXXX',
#   '.',
#   'The',
#   'caller',
#   'was',
#   'from',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   '(',
#   'FCC',
#   'Finance',
#   ',',
#   'LLC',
#   ')',
#   'and',
#   'they',
#   'usually',
#   'call',
#   'from',
#   'XXXX',
#   '.',
#   'However',
#   'today',
#   'they',
#   'spoofed',
#   'their',
#   'number',
#   'to',
#   'show',
#   'up',
#   'as',
#   '``',
#   'XXXX',
#   '``',
#   '(',
#   'XXXX',
#   ')',
#   'on',
#   'my',
#   'caller',
#   'ID',
#   '.',
#   'The',
#   'representative',
#   'from',
#   'FCC',
#   'called',
#   'and',
#   'asked',
#   'me',
#   'to',
#   'make',
#   'a',
#   'payment',
#   'with',
#   'my',
#   'debit',
#   'card',
#   'when',
#   'I',
#   'had',
#   'already',
#   'made',
#   'a',
#   'payment',
#   'this',
#   'month',
#   '.',
#   'It',
#   'was',
#   'taken',
#   'by',
#   'them',
#   'from',
#   'my',
#   'bank',
#   'account',
#   'on',
#   'XXXX/XXXX/XXXX',
#   '.',
#   'I',
#   'am',
#   'absolutely',
#   'sure',
#   'that',
#   'this',
#   'company',
#   'spoofed',
#   'their',
#   'number',
#   '.',
#   'Because',
#   'this',
#   'company',
#   "'s",
#   'intent',
#   'was',
#   'to',
#   'collect',
#   'more',
#   'money',
#   '``',
#   'spoofing',
#   '``',
#   'is',
#   'illegal',
#   'per',
#   'the',
#   'Federal',
#   'Communications',
#   'Commission',
#   '.',
#   'https',
#   ':',
#   '//www.fcc.gov/consumers/guides/spoofing-and-caller-id',
#   'I',
#   'feel',
#   'insulted',
#   'and',
#   'harassed',
#   'by',
#   'this',
#   'company',
#   "'s",
#   'practices',
#   'and',
#   'I',
#   "'m",
#   'curious',
#   'if',
#   'other',
#   'people',
#   'have',
#   'experienced',
#   'this',
#   'before',
#   'as',
#   'well',
#   '.'],
#  ['I',
#   'have',
#   'gotten',
#   '7',
#   'calls',
#   'from',
#   'AR',
#   'Resources',
#   'looking',
#   'for',
#   'a',
#   'person',
#   'who',
#   'is',
#   'not',
#   'authorized',
#   'to',
#   'use',
#   'our',
#   'phone',
#   '.',
#   'I',
#   'have',
#   'called',
#   'them',
#   'three',
#   'times',
#   'and',
#   'they',
#   'told',
#   'me',
#   'they',
#   'would',
#   'take',
#   'our',
#   'number',
#   'off',
#   'their',
#   'list',
#   '.',
#   'I',
#   'keep',
#   'getting',
#   'calls',
#   'so',
#   'started',
#   'to',
#   'document',
#   '.',
#   'I',
#   'received',
#   'a',
#   'call',
#   'on',
#   'XX/XX/XXXX',
#   'at',
#   'XXXX',
#   'XXXX',
#   '.',
#   'I',
#   'called',
#   'them',
#   'to',
#   'report',
#   'it',
#   ',',
#   'spoke',
#   'with',
#   'XXXX',
#   ',',
#   'who',
#   'told',
#   'me',
#   'she',
#   'removed',
#   'it',
#   'from',
#   'the',
#   'list',
#   'at',
#   'XXXX',
#   'XXXX',
#   'on',
#   'XX/XX/XXXX',
#   '.',
#   'At',
#   'XXXX',
#   'XXXX',
#   'on',
#   'XX/XX/XXXX',
#   'I',
#   'received',
#   'another',
#   'call',
#   '.',
#   'I',
#   'called',
#   'back',
#   'again',
#   ',',
#   'speaking',
#   'to',
#   'a',
#   'very',
#   'rude',
#   'XXXX',
#   ',',
#   'who',
#   'said',
#   'she',
#   'removed',
#   'my',
#   'name',
#   'from',
#   'the',
#   'list',
#   '.',
#   'I',
#   'asked',
#   'to',
#   'be',
#   'connected',
#   'to',
#   'a',
#   'supervisor',
#   'and',
#   'she',
#   'connected',
#   'me',
#   'to',
#   'XXXX',
#   ',',
#   'who',
#   'did',
#   'not',
#   'pick',
#   'up',
#   '.',
#   'I',
#   'left',
#   'a',
#   'message',
#   'asking',
#   'her',
#   'to',
#   'contact',
#   'me',
#   '.',
#   'XXXX',
#   'told',
#   'me',
#   'they',
#   'were',
#   'a',
#   'call',
#   'center',
#   '.',
#   'Please',
#   'stop',
#   'the',
#   'calls',
#   '-',
#   '7',
#   'times',
#   'I',
#   "'ve",
#   'been',
#   'told',
#   'I',
#   'was',
#   'being',
#   'taken',
#   'off',
#   'the',
#   'list',
#   '.',
#   'After',
#   '35',
#   'years',
#   ',',
#   'I',
#   "'m",
#   'considering',
#   'changing',
#   'my',
#   'phone',
#   'number',
#   '-',
#   'that',
#   'is',
#   'not',
#   'right',
#   '.',
#   'This',
#   'is',
#   'harassment',
#   '.',
#   'Thank',
#   'you',
#   '.'],
#  ['I',
#   'APPARENTLY',
#   'HAVE',
#   'AN',
#   'OUTSTANDING',
#   'DEBT',
#   'WITH',
#   'XXXX',
#   'XXXX',
#   '.',
#   'THEY',
#   'SENT',
#   'THE',
#   'ACCOUNT',
#   'TO',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   '.',
#   'THIS',
#   'COLLECTION',
#   'COMPANY',
#   'CALLS',
#   'MY',
#   'WORK',
#   'AND',
#   'CELL',
#   'SEVERAL',
#   'TIMES',
#   'A',
#   'DAY',
#   '.',
#   'UP',
#   'TO',
#   '6',
#   'TIMES',
#   'A',
#   'DAY',
#   '.',
#   'I',
#   'TRY',
#   'TO',
#   'TELL',
#   'THE',
#   'COMPANY',
#   'TO',
#   'STOP',
#   'CALLING',
#   'ME',
#   'AND',
#   'THEY',
#   'HANG',
#   'UP',
#   'LAUGHING',
#   '.',
#   'I',
#   'HAVE',
#   'NOT',
#   'RECEIVED',
#   'ANY',
#   'PAPERWORK',
#   'FROM',
#   'THIS',
#   'COMPANY',
#   '.',
#   'AND',
#   'XXXX',
#   'XXXX',
#   'REFUSE',
#   'TO',
#   'SPEAK',
#   'WITH',
#   'ME',
#   '.',
#   'I',
#   'HAVE',
#   'MAILED',
#   'IN',
#   'A',
#   'CEASE',
#   'AND',
#   'DESIST',
#   ',',
#   'AND',
#   'I',
#   'HAVE',
#   'CALLED',
#   'THEM',
#   'TO',
#   'GET',
#   'THEIR',
#   'FAX',
#   'NUMBER',
#   'TO',
#   'SEND',
#   'IN',
#   'THE',
#   'PAPERWORK-THEY',
#   'KEEP',
#   'GIVING',
#   'ME',
#   'DIFFERENT',
#   'ONES',
#   '(',
#   'FAX',
#   '#',
#   'XXXX',
#   ')',
#   'I',
#   'DO',
#   "N'T",
#   'OWE',
#   'ANY',
#   'MONEY',
#   'TO',
#   'XXXX',
#   ',',
#   'I',
#   'CLOSED',
#   'THE',
#   'ACCOUNT',
#   'WITH',
#   'A',
#   'XXXX',
#   'BALANCE',
#   'AND',
#   'TURNED',
#   'IN',
#   'ALL',
#   'OF',
#   'MY',
#   'EQUIPMENT',
#   'THAT',
#   'I',
#   'WAS',
#   'RENTING',
#   '.',
#   'AND',
#   'SO',
#   'DID',
#   'MY',
#   'WIFE',
#   '.'],
#  ['This',
#   'is',
#   'my',
#   'Second',
#   'attempt',
#   'to',
#   'have',
#   'the',
#   'problem',
#   'resolved',
#   '.',
#   'I',
#   'requested',
#   'to',
#   'have',
#   'Accounts',
#   'verified',
#   'that',
#   'are',
#   'being',
#   'reported',
#   'on',
#   'my',
#   'CR',
#   '.',
#   'I',
#   'still',
#   'have',
#   'not',
#   'received',
#   'any',
#   'correspondence',
#   'into',
#   'the',
#   'investigation',
#   'of',
#   'these',
#   'accounts.According',
#   'to',
#   'the',
#   'Fair',
#   'Credit',
#   'Reporting',
#   'Act',
#   ',',
#   'Section',
#   '609',
#   '(',
#   'a',
#   ')',
#   '(',
#   '1',
#   ')',
#   '(',
#   'A',
#   ')',
#   ',',
#   'you',
#   'are',
#   'required',
#   'by',
#   'federal',
#   'law',
#   'to',
#   'verify',
#   '-through',
#   'the',
#   'physical',
#   'verification',
#   'of',
#   'the',
#   'original',
#   'signed',
#   'consumer',
#   'contract',
#   '-any',
#   'and',
#   'all',
#   'accounts',
#   'you',
#   'post',
#   'on',
#   'a',
#   'credit',
#   'report',
#   '.',
#   'Otherwise',
#   ',',
#   'anyone',
#   'paying',
#   'for',
#   'your',
#   'reporting',
#   'services',
#   'could',
#   'fax',
#   ',',
#   'mail',
#   'or',
#   'email',
#   'in',
#   'a',
#   'fraudulent',
#   'account',
#   '.',
#   'I',
#   'demand',
#   'to',
#   'see',
#   'Verifiable',
#   'Proof',
#   '(',
#   'an',
#   'original',
#   'Consumer',
#   'Contract',
#   'with',
#   'my',
#   'Signature',
#   'on',
#   'it',
#   ')',
#   'you',
#   'have',
#   'on',
#   'file',
#   'of',
#   'the',
#   'accounts',
#   'listed',
#   'below',
#   '.',
#   'Your',
#   'failure',
#   'to',
#   'positively',
#   'verify',
#   'these',
#   'accounts',
#   'has',
#   'hurt',
#   'my',
#   'ability',
#   'to',
#   'obtain',
#   'credit',
#   '.',
#   'Under',
#   'the',
#   'FCRA',
#   ',',
#   'unverified',
#   'accounts',
#   'must',
#   'be',
#   'removed',
#   'and',
#   'if',
#   'you',
#   'are',
#   'unable',
#   'to',
#   'provide',
#   'me',
#   'a',
#   'copy',
#   'of',
#   'verifiable',
#   'proof',
#   ',',
#   'you',
#   'must',
#   'remove',
#   'the',
#   'accounts',
#   'listed',
#   'below',
#   '.'],
#  ['this',
#   'account',
#   'is',
#   'old',
#   ',',
#   'and',
#   'should',
#   'have',
#   'been',
#   'removed',
#   '.',
#   'it',
#   'appears',
#   'to',
#   'have',
#   'been',
#   'transferred',
#   'several',
#   'times',
#   ',',
#   'they',
#   'mention',
#   'continue',
#   'to',
#   'update',
#   'as',
#   'un',
#   'paid',
#   'on',
#   'my',
#   'credit',
#   'file',
#   ',',
#   'what',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'my',
#   'life',
#   '.',
#   'another',
#   'threat',
#   'involving',
#   'my',
#   'way',
#   'of',
#   'living',
#   '.',
#   'amazing',
#   'how',
#   'I',
#   "'m",
#   'following',
#   'the',
#   'law',
#   'and',
#   'getting',
#   'robbed',
#   'and',
#   'bullied',
#   ',',
#   'controlled',
#   '.'],
#  ['On',
#   'XX/XX/2018',
#   ',',
#   'I',
#   'attempted',
#   'to',
#   'dispute',
#   'an',
#   'account',
#   'from',
#   'XXXX',
#   'XXXX',
#   '(',
#   '#',
#   'XXXX',
#   ')',
#   ',',
#   'this',
#   'account',
#   'was',
#   'added',
#   'to',
#   'my',
#   'personal',
#   'credit',
#   'file',
#   'through',
#   'theft',
#   'as',
#   'I',
#   'was',
#   'a',
#   'victim',
#   'of',
#   'Identity',
#   'theft',
#   'in',
#   'a',
#   'security',
#   'breach',
#   'with',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   '.',
#   'The',
#   'disputes',
#   'were',
#   'all',
#   'sent',
#   'via',
#   'certified',
#   'mail',
#   ',',
#   'yet',
#   'I',
#   'have',
#   'received',
#   'no',
#   'response',
#   'from',
#   'any',
#   'of',
#   'the',
#   'Reporting',
#   'Agencies',
#   'as',
#   'to',
#   'the',
#   'removal',
#   'of',
#   'this',
#   'fraudulent',
#   'account',
#   '.'],
#  ['Alleged',
#   'company',
#   'use',
#   'scare',
#   'tactics',
#   'to',
#   'threaten',
#   'me',
#   'to',
#   'pay',
#   '.',
#   'Funny',
#   'thing',
#   'is',
#   'it',
#   'used',
#   'a',
#   'fake',
#   'social',
#   'number',
#   'and',
#   'name',
#   'that',
#   'not',
#   'even',
#   'mine',
#   'yet',
#   'still',
#   'claim',
#   'I',
#   'MUST',
#   'pay',
#   '.',
#   'That',
#   "'s",
#   'clearly',
#   'identity',
#   'theft',
#   'written',
#   'out',
#   '.',
#   'Name',
#   'spelt',
#   'way',
#   'off',
#   'and',
#   'Ssn',
#   'number',
#   'used',
#   'is',
#   'off',
#   '.',
#   'That',
#   "'s",
#   'clear',
#   'identity',
#   'theft',
#   '.',
#   'They',
#   'ripping',
#   'off',
#   'me',
#   '.'],
#  ['On',
#   'the',
#   'credit',
#   'report',
#   'equifax',
#   'there',
#   'is',
#   'a',
#   'name',
#   'listed',
#   'there',
#   'that',
#   'I',
#   'have',
#   'never',
#   'seen',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'who',
#   'that',
#   'belongs',
#   'too',
#   'and',
#   'must',
#   'be',
#   'fixed'],
#  ['I',
#   'Filed',
#   'a',
#   'complaint',
#   '#',
#   'XXXX',
#   'on',
#   'BRIDGECREST',
#   'ACCEPTANCE',
#   'CORPORATION',
#   'on',
#   'XX/XX/XXXX',
#   ',',
#   'my',
#   'complaint',
#   'was',
#   'with',
#   'how',
#   'they',
#   'are',
#   'closing',
#   'the',
#   'account',
#   '.',
#   'BRIDGECREST',
#   'ACCEPTANCE',
#   'CORPORATION',
#   'responded',
#   'on',
#   'XX/XX/XXXX',
#   'and',
#   'the',
#   'complaint',
#   'was',
#   'closed',
#   ',',
#   'however',
#   'XXXX',
#   'still',
#   'did',
#   'not',
#   'file',
#   'the',
#   'GAP',
#   'insurrance',
#   '.',
#   'They',
#   'claim',
#   'that',
#   'the',
#   'total',
#   'amount',
#   'was',
#   'not',
#   'received',
#   ',',
#   'the',
#   'amount',
#   'was',
#   'short',
#   'by',
#   '{',
#   '$',
#   '4.00',
#   '}',
#   'and',
#   'the',
#   'GAP',
#   'could',
#   'not',
#   'be',
#   'filed',
#   'until',
#   'the',
#   'total',
#   'amount',
#   'was',
#   'paid',
#   '.',
#   'They',
#   'received',
#   'the',
#   'amount',
#   'on',
#   'XX/XX/XXXX',
#   ',',
#   'then',
#   'on',
#   'XX/XX/XXXX',
#   'the',
#   'differance',
#   'of',
#   '{',
#   '$',
#   '4.00',
#   '}',
#   'was',
#   'posted',
#   'to',
#   'my',
#   'account',
#   'and',
#   'still',
#   'waiting',
#   'for',
#   'the',
#   'GAP',
#   'to',
#   'close',
#   '.',
#   'XXXX',
#   'lack',
#   'of',
#   'attention',
#   'with',
#   'my',
#   'account',
#   'is',
#   'due',
#   'to',
#   'me',
#   'no',
#   'longer',
#   'wanting',
#   'to',
#   'use',
#   'thier',
#   'company',
#   'financing',
#   '.',
#   'thier',
#   'interst',
#   'rates',
#   'is',
#   'too',
#   'high',
#   'and',
#   'they',
#   'was',
#   'not',
#   'truthful',
#   'in',
#   'how',
#   'interest',
#   'was',
#   'accumulated',
#   '.',
#   'this',
#   'was',
#   'not',
#   'a',
#   'simple',
#   'interest',
#   'loan',
#   '.',
#   'they',
#   'will',
#   'receive',
#   '3',
#   'times',
#   'the',
#   'amout',
#   'of',
#   'the',
#   'vehicles',
#   'worth',
#   '.',
#   'My',
#   'vehicle',
#   'was',
#   'involve',
#   'in',
#   'an',
#   'accident',
#   'on',
#   'XX/XX/XXXX',
#   'and',
#   'as',
#   'of',
#   'XX/XX/XXXX',
#   'i',
#   'am',
#   'still',
#   'without',
#   'a',
#   'vehicle',
#   '.'],
#  ['In',
#   'late',
#   'XXXX',
#   'of',
#   '2017',
#   'I',
#   'requested',
#   'a',
#   'balance',
#   'transfer',
#   'from',
#   'my',
#   'Comenity',
#   'Bank',
#   'Visa',
#   'card',
#   'to',
#   'pay',
#   'off',
#   'a',
#   'high',
#   'balance',
#   'on',
#   'another',
#   'credit',
#   'card',
#   'I',
#   'have',
#   '.',
#   'On',
#   'XXXX',
#   'XXXX',
#   ',',
#   '2017',
#   'the',
#   'charge',
#   'posted',
#   'to',
#   'my',
#   'Comenity',
#   'Bank',
#   'Visa',
#   'card',
#   'account',
#   'however',
#   ',',
#   'as',
#   'of',
#   'today',
#   '(',
#   'XXXX',
#   'XXXX',
#   ',',
#   '2017',
#   ')',
#   'they',
#   'have',
#   'never',
#   'sent',
#   'the',
#   'money',
#   'to',
#   'pay',
#   'off',
#   'the',
#   'other',
#   'credit',
#   'card',
#   '.',
#   'I',
#   'have',
#   'tried',
#   'to',
#   'resolve',
#   'the',
#   'problem',
#   'with',
#   'several',
#   'phone',
#   'calls',
#   'to',
#   'Comenity',
#   'Bank',
#   'but',
#   'no',
#   'one',
#   'has',
#   'been',
#   'able',
#   'to',
#   'give',
#   'a',
#   'reasonable',
#   'explanation',
#   'of',
#   'why',
#   'they',
#   'are',
#   'charging',
#   'my',
#   'credit',
#   'card',
#   'account',
#   'without',
#   'actually',
#   'sending',
#   'the',
#   'money',
#   'to',
#   'pay',
#   'off',
#   'the',
#   'other',
#   'credit',
#   'card',
#   '.',
#   'I',
#   'have',
#   'also',
#   'sent',
#   'them',
#   'a',
#   'written',
#   'dispute',
#   'of',
#   'the',
#   'charge',
#   'but',
#   'have',
#   'received',
#   'no',
#   'response',
#   'yet',
#   '.'],
#  ['XXXX',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   ',',
#   'La',
#   'XXXX',
#   'XX/XX/XXXX',
#   'Dear',
#   'TransUnion/',
#   'XXXX/',
#   'XXXX',
#   ':',
#   'Please',
#   'have',
#   'the',
#   'fraudulent',
#   'account',
#   '(',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   ')',
#   'removed',
#   ';',
#   'XXXX',
#   'has',
#   'removed',
#   'it',
#   'and',
#   'it',
#   'has',
#   'been',
#   'reported',
#   'to',
#   'the',
#   'FTC',
#   '.',
#   'Also',
#   ',',
#   'the',
#   'inquiries',
#   'on',
#   'my',
#   'credit',
#   'report',
#   ',',
#   'which',
#   'I',
#   'did',
#   'not',
#   'authorize',
#   'need',
#   'to',
#   'be',
#   'removed',
#   'as',
#   'well',
#   '.',
#   '<',
#   'P/',
#   '>',
#   'Also',
#   ',',
#   'I',
#   'contacted',
#   'TransUnion/',
#   'XXXX',
#   'XX/XX/XXXX',
#   '.',
#   '<',
#   'P/',
#   '>',
#   '<',
#   'P/',
#   '>',
#   '<',
#   'P/',
#   '>',
#   'Sincerely',
#   ',',
#   'XXXX',
#   'XXXX',
#   '(',
#   'XXXX',
#   ')',
#   'XXXX'],
#  ['I',
#   'have',
#   'sent',
#   'more',
#   'than',
#   'XXXX',
#   'letters',
#   'to',
#   'Portfolio',
#   'recovery',
#   ',',
#   'asking',
#   'for',
#   'VALIDATION',
#   'bearing',
#   'MY',
#   'SIGNATURE',
#   'of',
#   'a',
#   'debt',
#   'for',
#   'the',
#   'amount',
#   'of',
#   '{',
#   '$',
#   '470.00',
#   '}',
#   ',',
#   'made',
#   'pursuant',
#   'to',
#   'the',
#   'Fair',
#   'Debt',
#   'Collection',
#   'Practices',
#   'Act',
#   '.',
#   'I',
#   'do',
#   "n't",
#   'have',
#   'any',
#   'debt',
#   'with',
#   'this',
#   'compa',
#   'ny',
#   'nor',
#   'any',
#   'contract',
#   'with',
#   'them',
#   '.',
#   'Portfolio',
#   'recovery',
#   'keep',
#   'sending',
#   'letters',
#   'that',
#   'they',
#   'VERIFIED',
#   'the',
#   'debt',
#   'but',
#   'failed',
#   'twice',
#   'to',
#   'provided',
#   'me',
#   'with',
#   'my',
#   'Signature',
#   'as',
#   'VALIDATION',
#   'of',
#   'the',
#   'debt',
#   'they',
#   'say',
#   'I',
#   'owe',
#   '.',
#   'Last',
#   'letter',
#   'they',
#   'sent',
#   'was',
#   'for',
#   'a',
#   'settlement',
#   'and',
#   'still',
#   'no',
#   'VALIDATION',
#   'of',
#   'this',
#   'debt',
#   'bearing',
#   'my',
#   'signature',
#   '.',
#   'They',
#   'marked',
#   'on',
#   'my',
#   'credit',
#   'report',
#   '``',
#   'Dispute',
#   'Resolved',
#   '``',
#   'which',
#   'I',
#   'do',
#   "n't",
#   'agree',
#   '.',
#   'I',
#   'could',
#   "n't",
#   'get',
#   'a',
#   'loan',
#   'for',
#   'a',
#   'house',
#   'because',
#   'of',
#   'this',
#   'damage',
#   'to',
#   'my',
#   'credit',
#   '.',
#   'So',
#   'for',
#   'a',
#   'debt',
#   'that',
#   'I',
#   'do',
#   "n't",
#   'owe',
#   ',',
#   'is',
#   'a',
#   'violation',
#   'of',
#   'the',
#   'Fair',
#   'Debt',
#   'Collection',
#   'Practices',
#   'Act',
#   'FDCPA',
#   '807',
#   '[',
#   '15',
#   'USC',
#   '1962e',
#   ']',
#   ';',
#   'therefore',
#   ',',
#   'if',
#   'you',
#   'can',
#   'not',
#   'validate',
#   'the',
#   'debt',
#   ',',
#   'you',
#   'must',
#   'request',
#   'that',
#   'all',
#   'credit',
#   'reporting',
#   'agencies',
#   'delete',
#   'the',
#   'entry',
#   '.',
#   'I',
#   "'ve",
#   'been',
#   'keeping',
#   'records',
#   'of',
#   'all',
#   'documentation',
#   'between',
#   'Portfolio',
#   'Recovery',
#   'Services',
#   'and',
#   'me',
#   '.'],
#  ['I',
#   'transferred',
#   '(',
#   'Wire',
#   'Transfer',
#   ')',
#   'money',
#   'from',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'on',
#   'XXXX/XXXX/XXXX',
#   'to',
#   'Coinbase',
#   ',',
#   'Inc',
#   'amount',
#   'of',
#   'XXXX',
#   'USD',
#   '.',
#   'The',
#   'Money',
#   'was',
#   'transferred',
#   'same',
#   'day',
#   'from',
#   'my',
#   'bank',
#   'account',
#   '.',
#   'I',
#   'have',
#   'contacted',
#   'the',
#   'recipient',
#   'through',
#   'there',
#   'web',
#   'site',
#   'asking',
#   'about',
#   'the',
#   'status',
#   'of',
#   'the',
#   'transfer',
#   '.',
#   'I',
#   'have',
#   'requested',
#   'them',
#   '5',
#   'to',
#   '6',
#   'times',
#   'in',
#   'past',
#   '5',
#   'days',
#   '.',
#   'They',
#   'responded',
#   'for',
#   'my',
#   '1st',
#   'request',
#   'asking',
#   'the',
#   'Federal',
#   'Reference',
#   'number',
#   'for',
#   'the',
#   'transfer',
#   '.',
#   'I',
#   'sent',
#   'the',
#   'required',
#   'details',
#   ',',
#   'but',
#   'till',
#   'date',
#   'no',
#   'response',
#   'from',
#   'them',
#   '.',
#   'The',
#   'CaseID',
#   'with',
#   'CoinBase',
#   'Inc',
#   'is',
#   'XXXX',
#   '.',
#   'Attaching',
#   'the',
#   'Email',
#   'exchange',
#   'and',
#   'Bank',
#   'Statement',
#   '(',
#   'To',
#   'Confirm',
#   'the',
#   'money',
#   'was',
#   'transferred',
#   'from',
#   'my',
#   'account',
#   ')',
#   '.'],
#  ['I',
#   'have',
#   'been',
#   'trying',
#   'to',
#   'open',
#   'a',
#   'small',
#   'XXXX',
#   'business',
#   'since',
#   'XX/XX/XXXX',
#   'and',
#   'had',
#   'worked',
#   'with',
#   'XXXX',
#   'of',
#   'Chase',
#   'Bank',
#   'in',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   'for',
#   'business',
#   'funding',
#   '.',
#   'During',
#   'our',
#   'relations',
#   'she',
#   'promised',
#   'me',
#   'she',
#   'was',
#   'diligently',
#   'going',
#   'to',
#   'see',
#   'if',
#   'she',
#   'could',
#   'get',
#   'my',
#   'business',
#   'funding',
#   'with',
#   'Chase',
#   ',',
#   'I',
#   'was',
#   'asking',
#   'for',
#   'a',
#   'XXXX',
#   'loan',
#   '.',
#   'After',
#   'waiting',
#   'weeks',
#   'for',
#   'a',
#   'return',
#   'call',
#   'regarding',
#   'her',
#   'promise',
#   ',',
#   'I',
#   'never',
#   'heard',
#   'back',
#   'from',
#   'her',
#   'to',
#   'this',
#   'day',
#   '.',
#   'Without',
#   'funding',
#   'from',
#   'Chase',
#   ',',
#   'we',
#   'were',
#   'left',
#   'with',
#   'no',
#   'choice',
#   'to',
#   'get',
#   'a',
#   '$',
#   'XXXX',
#   'loan',
#   'from',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'in',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   '(',
#   'formerly',
#   'known',
#   'as',
#   'Chase',
#   'Bank',
#   '!',
#   ')',
#   'for',
#   '33',
#   '%',
#   'interest',
#   'and',
#   'our',
#   '2',
#   'XXXX',
#   'XXXX',
#   'motorcycles',
#   'as',
#   'collateral.Our',
#   'thoughts',
#   'are',
#   'to',
#   'pay',
#   'that',
#   'loan',
#   'in',
#   'the',
#   'shortest',
#   'time',
#   'possible',
#   'once',
#   'we',
#   'are',
#   'able',
#   'to',
#   'open',
#   'our',
#   'doors',
#   'for',
#   'revenue',
#   '.',
#   'This',
#   'money',
#   'now',
#   'was',
#   'not',
#   'only',
#   'the',
#   'money',
#   'we',
#   'needed',
#   'but',
#   'it',
#   'also',
#   'has',
#   '$',
#   'XXXX',
#   'of',
#   'our',
#   'property',
#   'tied',
#   'to',
#   'it.4',
#   'days',
#   'before',
#   'we',
#   'were',
#   'to',
#   'secure',
#   'the',
#   'loan',
#   'I',
#   'opted',
#   'to',
#   'open',
#   'my',
#   'business',
#   'checking',
#   'account',
#   'with',
#   'XXXX',
#   'at',
#   'the',
#   '2nd',
#   'Chase',
#   'branch',
#   'in',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   '.',
#   'We',
#   'did',
#   'not',
#   'want',
#   'to',
#   'sign',
#   'for',
#   'that',
#   'loan',
#   'but',
#   'we',
#   'needed',
#   'to',
#   ',',
#   'to',
#   'complete',
#   'my',
#   'business',
#   'plan',
#   'purchase',
#   '.',
#   'The',
#   'ACH',
#   'deposit',
#   'happened',
#   'XX/XX/XXXX',
#   'and',
#   'XXXX',
#   'explained',
#   'I',
#   'would',
#   'be',
#   'able',
#   'to',
#   'get',
#   'a',
#   '$',
#   'XXXXcashiers',
#   'check',
#   'as',
#   'soon',
#   'as',
#   'the',
#   'funds',
#   'were',
#   'showing',
#   'in',
#   'my',
#   'account',
#   '.',
#   'I',
#   'checked',
#   'my',
#   'account',
#   'Friday',
#   'morning',
#   'and',
#   'the',
#   'loan',
#   'deposit',
#   'was',
#   'successful',
#   '.',
#   'I',
#   'did',
#   "n't",
#   'make',
#   'it',
#   'to',
#   'the',
#   'bank',
#   'Friday',
#   ',',
#   'so',
#   'I',
#   'went',
#   'to',
#   'Chase',
#   'Bank',
#   'Saturday',
#   ',',
#   'XX/XX/XXXX',
#   'before',
#   'we',
#   'headed',
#   'to',
#   'Illinois',
#   'to',
#   'purchase',
#   'and',
#   'move',
#   'my',
#   'XXXX',
#   '.',
#   'Chase',
#   'did',
#   'NOT',
#   'have',
#   'any',
#   'hold',
#   'on',
#   'my',
#   'business',
#   'funds',
#   'until',
#   'XXXX',
#   'decided',
#   'to',
#   'put',
#   'a',
#   '``',
#   'suspicious',
#   'activity',
#   'alert',
#   '``',
#   'on',
#   'my',
#   'business',
#   'checking',
#   'account',
#   'making',
#   'those',
#   'funds',
#   'unavailable',
#   'to',
#   'me',
#   '.',
#   'She',
#   'ALONE',
#   'sabotaged',
#   'my',
#   'move',
#   'that',
#   'was',
#   'very',
#   'time',
#   'sensitive',
#   'and',
#   'prescheduled',
#   '.',
#   'She',
#   'vindictively',
#   'made',
#   'my',
#   'funds',
#   'unavailable',
#   'to',
#   'me',
#   'out',
#   'of',
#   'spite',
#   ',',
#   'she',
#   'apparently',
#   'was',
#   'upset',
#   'because',
#   'I',
#   'chose',
#   'a',
#   'different',
#   'Chase',
#   'branch',
#   'to',
#   'open',
#   'my',
#   'small',
#   'business',
#   'checking',
#   'account',
#   '.',
#   'The',
#   'money',
#   'that',
#   'was',
#   'deposited',
#   'was',
#   'an',
#   'ACH',
#   'deposit',
#   'from',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'in',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   'formerly',
#   'known',
#   'as',
#   'Chase',
#   'bank',
#   '.',
#   'The',
#   'deposit',
#   'was',
#   'cleared',
#   'and',
#   'considered',
#   'hard',
#   'cash',
#   'deposit',
#   'when',
#   'I',
#   'went',
#   'into',
#   'her',
#   'branch',
#   'for',
#   'a',
#   'cashiers',
#   'check',
#   'for',
#   'the',
#   'deposit',
#   'of',
#   'my',
#   'XXXX',
#   'XXXX',
#   'purchase',
#   '.',
#   'This',
#   'was',
#   'supposed',
#   'to',
#   'happen',
#   'XX/XX/XXXX',
#   'at',
#   'XXXX',
#   'in',
#   'Illinois',
#   'to',
#   'move',
#   'the',
#   'XXXX',
#   'to',
#   'XXXX',
#   ',',
#   'WI',
#   '.',
#   'The',
#   'move',
#   'needed',
#   'to',
#   'be',
#   'done',
#   'in',
#   'a',
#   '2',
#   'day',
#   'process',
#   'as',
#   'XXXX',
#   '.',
#   'pieces',
#   'of',
#   'equipment',
#   'and',
#   'the',
#   'entire',
#   'XXXX',
#   'was',
#   'being',
#   'moved',
#   '2',
#   'hours',
#   'away',
#   '.',
#   'She',
#   'told',
#   'me',
#   'I',
#   'could',
#   'not',
#   'get',
#   'the',
#   '{',
#   '$',
#   '5800.00',
#   '}',
#   'and',
#   'could',
#   'not',
#   'explain',
#   'why',
#   '.',
#   'I',
#   'was',
#   'wearing',
#   'a',
#   'distinctive',
#   'bright',
#   'blue',
#   'XXXX',
#   'jogging',
#   'suit',
#   ',',
#   'not',
#   'knowing',
#   'when',
#   'left',
#   'the',
#   'branch',
#   'without',
#   'my',
#   'deposit',
#   ',',
#   'she',
#   'put',
#   'an',
#   '``',
#   'suspicious',
#   'activity',
#   'alert',
#   '``',
#   'on',
#   'my',
#   'account',
#   'with',
#   'my',
#   'description',
#   'and',
#   'copy',
#   'of',
#   'DL',
#   '!',
#   'She',
#   'said',
#   'she',
#   'was',
#   'going',
#   'to',
#   'call',
#   'customer',
#   'service',
#   'and',
#   'that',
#   'she',
#   'would',
#   'call',
#   'me',
#   'back',
#   'as',
#   'we',
#   'headed',
#   'to',
#   'Illinois',
#   '.',
#   'Being',
#   'a',
#   'Saturday',
#   'banks',
#   'were',
#   'only',
#   'open',
#   'until',
#   'XXXX',
#   '.',
#   'She',
#   'had',
#   "n't",
#   'called',
#   'me',
#   'back',
#   ',',
#   'so',
#   'at',
#   'XXXX',
#   'on',
#   'my',
#   'way',
#   'to',
#   'Illinois',
#   'to',
#   'purchase',
#   'my',
#   'dream',
#   ',',
#   'I',
#   'opted',
#   'to',
#   'stop',
#   'at',
#   'the',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   'Chase',
#   'bank',
#   'to',
#   'attempt',
#   'to',
#   'get',
#   'the',
#   'deposit',
#   'I',
#   'needed',
#   '.',
#   'I',
#   'was',
#   'greeted',
#   'with',
#   'EVERY',
#   'teller',
#   "'s",
#   'eye',
#   'contact',
#   'and',
#   'as',
#   'I',
#   'was',
#   'waiting',
#   'to',
#   'see',
#   'a',
#   'teller',
#   ',',
#   'the',
#   'branch',
#   'manager',
#   'says',
#   '``',
#   'everything',
#   'ok',
#   "ma'am",
#   '?',
#   '``',
#   'I',
#   'turned',
#   'around',
#   'and',
#   'responded',
#   '``',
#   'yes',
#   ',',
#   'I',
#   "'m",
#   'fine',
#   '``',
#   'and',
#   'I',
#   'pondered',
#   'on',
#   'his',
#   'attentiveness',
#   'as',
#   'well',
#   '...',
#   'Note',
#   ':',
#   'bright',
#   'blue',
#   'jogging',
#   'suit',
#   '.',
#   'Still',
#   'not',
#   'knowing',
#   'that',
#   'XXXX',
#   'placed',
#   'a',
#   'flag',
#   'on',
#   'me',
#   ',',
#   'I',
#   'turned',
#   'around',
#   'to',
#   'the',
#   'branch',
#   'manager',
#   'and',
#   'asked',
#   '``',
#   'Maybe',
#   'you',
#   'can',
#   'help',
#   'me',
#   ',',
#   'I',
#   "'m",
#   'having',
#   'a',
#   'problem',
#   'getting',
#   'a',
#   'cashiers',
#   'check',
#   'from',
#   'my',
#   'business',
#   'account',
#   '``',
#   '.',
#   'While',
#   'sitting',
#   'in',
#   'his',
#   'cubicle',
#   'explaining',
#   'the',
#   'problem',
#   'getting',
#   'the',
#   'deposit',
#   'check',
#   'he',
#   'continued',
#   'to',
#   'gaze',
#   'at',
#   'his',
#   'computer',
#   'and',
#   'interrogate',
#   'me',
#   'on',
#   'my',
#   'intentions',
#   'of',
#   'my',
#   'money',
#   '!',
#   'At',
#   'this',
#   'point',
#   'I',
#   'was',
#   'still',
#   'unaware',
#   'of',
#   'the',
#   '``',
#   'suspicious',
#   'activity',
#   '``',
#   'alert',
#   'XXXX',
#   'placed',
#   'on',
#   'my',
#   'account',
#   'making',
#   'MY',
#   'business',
#   'money',
#   'inaccessible',
#   '!',
#   'I',
#   'opted',
#   'to',
#   'speaker',
#   'phone',
#   'the',
#   'XXXX',
#   'owner',
#   'I',
#   'was',
#   'on',
#   'my',
#   'way',
#   'to',
#   'meet',
#   'in',
#   'IL',
#   'and',
#   'asked',
#   'if',
#   'we',
#   'could',
#   'just',
#   'transfer',
#   'the',
#   'money',
#   'into',
#   'HIS',
#   'Chase',
#   'account',
#   '.',
#   'The',
#   'XXXX',
#   'XXXX',
#   ',',
#   'WI',
#   'manager',
#   'interrupted',
#   'us',
#   'and',
#   'said',
#   '``',
#   'well',
#   ',',
#   'wait',
#   ',',
#   'you',
#   'need',
#   'XXXX',
#   'cash',
#   '?',
#   '``',
#   'On',
#   'speaker',
#   'phone',
#   ',',
#   'XXXX',
#   'and',
#   'I',
#   'say',
#   'fine',
#   ',',
#   'cash',
#   'is',
#   'king',
#   '!',
#   'The',
#   'banker',
#   'said',
#   '``',
#   'ok',
#   'i',
#   'will',
#   'get',
#   'your',
#   'cash',
#   '``',
#   '.',
#   'I',
#   'preferred',
#   'a',
#   'check',
#   'but',
#   'I',
#   'hung',
#   'up',
#   'with',
#   'XXXX',
#   'and',
#   'said',
#   'I',
#   'would',
#   'be',
#   'back',
#   'on',
#   'my',
#   'way',
#   'with',
#   'XXXX',
#   'cash',
#   '.',
#   'I',
#   'patiently',
#   'waited',
#   '6-7',
#   'minutes',
#   ',',
#   'anxious',
#   'to',
#   'be',
#   'on',
#   'my',
#   'way',
#   'to',
#   'meet',
#   'XXXX',
#   ',',
#   'movers',
#   ',',
#   'equipment',
#   'technicians',
#   ',',
#   'friends',
#   'and',
#   'buy',
#   'my',
#   'dream',
#   '.',
#   'The',
#   'manager',
#   'comes',
#   'back',
#   'with',
#   'his',
#   'little',
#   'green',
#   'bank',
#   'bag',
#   ',',
#   'placed',
#   'it',
#   'on',
#   'his',
#   'desk',
#   'and',
#   'said',
#   '``',
#   'yeah',
#   ',',
#   'this',
#   'is',
#   "n't",
#   'going',
#   'to',
#   'happen',
#   'today',
#   '.',
#   'You',
#   'will',
#   'have',
#   'to',
#   'go',
#   'back',
#   'to',
#   'the',
#   'XXXX',
#   'XXXX',
#   'branch',
#   'that',
#   'you',
#   'opened',
#   'your',
#   'account',
#   'at.',
#   '``',
#   'I',
#   'said',
#   '``',
#   'WHAT',
#   '!',
#   'I',
#   'am',
#   'on',
#   'my',
#   'way',
#   'to',
#   'Illinois',
#   'and',
#   'it',
#   "'s",
#   'almost',
#   'XXXX',
#   ',',
#   'I',
#   'ca',
#   "n't",
#   'go',
#   'back',
#   'to',
#   'XXXX',
#   'XXXX',
#   '!',
#   'This',
#   'is',
#   'a',
#   'Chase',
#   'Bank',
#   'right',
#   '?',
#   '!',
#   '``',
#   'He',
#   'again',
#   'says',
#   '``',
#   'yeah',
#   ',',
#   'all',
#   'I',
#   'can',
#   'tell',
#   'you',
#   'is',
#   'go',
#   'back',
#   'to',
#   'the',
#   'XXXX',
#   'XXXX',
#   'location',
#   '``',
#   'I',
#   'started',
#   'balling',
#   'and',
#   'literally',
#   'shaking',
#   'asking',
#   '``',
#   'Why',
#   '?',
#   '?',
#   'I',
#   'ca',
#   "n't",
#   'move',
#   'the',
#   ...],
#  ['Hi',
#   'my',
#   'name',
#   'is',
#   'XXXX',
#   'XXXX',
#   'I',
#   'am',
#   'reaching',
#   'out',
#   'to',
#   'you',
#   'do',
#   'to',
#   'my',
#   'Experian',
#   'credit',
#   'report',
#   '.',
#   'Couple',
#   'months',
#   'back',
#   'I',
#   'obtained',
#   'a',
#   'copy',
#   'of',
#   'my',
#   'Experian',
#   'credit',
#   'report',
#   'and',
#   'on',
#   'my',
#   'credit',
#   'report',
#   'there',
#   'was',
#   'a',
#   'duplicate',
#   'account',
#   'that',
#   'was',
#   'posting',
#   'twice',
#   '.',
#   'One',
#   'with',
#   'no',
#   'data',
#   'and',
#   'one',
#   'with',
#   'correct',
#   'data',
#   'So',
#   'I',
#   'contacted',
#   'Experian',
#   'and',
#   'had',
#   'it',
#   'disputed',
#   '.',
#   'The',
#   'consumers',
#   'name',
#   'that',
#   'I',
#   'was',
#   'disputing',
#   'for',
#   'posting',
#   'duplicate',
#   'was',
#   'XXXX',
#   'XXXX',
#   'But',
#   'unfortunately',
#   'Experian',
#   'member',
#   'deleted',
#   'an',
#   'active',
#   'account',
#   'from',
#   'a',
#   'different',
#   'company',
#   'the',
#   'name',
#   'for',
#   'that',
#   'company',
#   'was',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'due',
#   'to',
#   'the',
#   'wrong',
#   'deletion',
#   'my',
#   'credit',
#   'score',
#   'took',
#   'an',
#   'impact',
#   'of',
#   'dropping',
#   'my',
#   'score',
#   'lower',
#   '.',
#   'I',
#   'have',
#   'tried',
#   'contacting',
#   'Experian',
#   'multiple',
#   'times',
#   'but',
#   'every',
#   'time',
#   'I',
#   'do',
#   'contact',
#   'them',
#   'I',
#   'am',
#   'greeted',
#   'with',
#   'the',
#   'foreigner',
#   'that',
#   'does',
#   'not',
#   'understand',
#   'what',
#   'Im',
#   'trying',
#   'to',
#   'explain',
#   'every',
#   'time',
#   'I',
#   'tell',
#   'him',
#   'they',
#   'deleted',
#   'the',
#   'wrong',
#   'one',
#   'he',
#   'tells',
#   'me',
#   'yes',
#   'sir',
#   'we',
#   'deleted',
#   'XXXX',
#   'XXXX',
#   'and',
#   'I',
#   'tell',
#   'him',
#   'know',
#   'yous',
#   'deleted',
#   'the',
#   'wrong',
#   'one',
#   'then',
#   'then',
#   'they',
#   'put',
#   'someone',
#   'else',
#   'that',
#   'still',
#   'dont',
#   'get',
#   'that',
#   'they',
#   'deleted',
#   'the',
#   'wrong',
#   'credit',
#   'card',
#   'posting',
#   '.',
#   'I',
#   'had',
#   'contacted',
#   'XXXX',
#   'XXXX',
#   'and',
#   'let',
#   'them',
#   'know',
#   'they',
#   'were',
#   'going',
#   'to',
#   'post',
#   'another',
#   'months',
#   'worth',
#   'on',
#   'my',
#   'credit',
#   'report',
#   'but',
#   'my',
#   'concern',
#   'is',
#   'my',
#   'past',
#   'good',
#   'credit',
#   'report',
#   'history',
#   'is',
#   'now',
#   'missing',
#   'due',
#   'to',
#   'experience',
#   'deleting',
#   'the',
#   'wrong',
#   'file',
#   '.'],
#  ['I',
#   "'m",
#   'XXXX',
#   'now',
#   'and',
#   'I',
#   "'m",
#   'trying',
#   'to',
#   'get',
#   'my',
#   'free',
#   'credit',
#   'report',
#   'and',
#   'I',
#   'keep',
#   'getting',
#   'my',
#   'information',
#   'does',
#   "n't",
#   'match',
#   'my',
#   'record',
#   '?'],
#  ['This',
#   'number',
#   'calls',
#   'me',
#   'repeatedly',
#   'and',
#   'says',
#   'I',
#   'owe',
#   'a',
#   'debt',
#   'and',
#   'they',
#   'are',
#   'taking',
#   'legal',
#   'action',
#   '.',
#   'I',
#   'dont',
#   'owe',
#   'a',
#   'debt',
#   'and',
#   'they',
#   'leave',
#   'nasty',
#   'messages',
#   'on',
#   'my',
#   'phone',
#   '.',
#   'They',
#   'wont',
#   'say',
#   'who',
#   'they',
#   'are',
#   'just',
#   'say',
#   'legal',
#   'department'],
#  ['This',
#   'Phone',
#   'Number',
#   'XXXX',
#   'is',
#   'Midland',
#   'Credit',
#   '.',
#   'they',
#   'have',
#   'called',
#   'me',
#   'XXXX',
#   'a',
#   'day',
#   'for',
#   'months',
#   'and',
#   'even',
#   'on',
#   'XXXX',
#   'and',
#   'XXXX',
#   ',',
#   'looking',
#   'for',
#   'someone',
#   'who',
#   'is',
#   'not',
#   'me',
#   '.',
#   'I',
#   'have',
#   'asked',
#   'them',
#   'numerous',
#   'times',
#   'to',
#   'stop',
#   'that',
#   'i',
#   'was',
#   'not',
#   'the',
#   'person',
#   'they',
#   'are',
#   'looking',
#   'for',
#   'and',
#   'they',
#   'still',
#   'call',
#   'me',
#   'even',
# ...
#   'file',
#   'as',
#   'a',
#   'fraud',
#   'or',
#   'pay',
#   'it',
#   '.',
#   'they',
#   'will',
#   'not',
#   'substantiate',
#   'this',
#   'debt',
#   'as',
#   'being',
#   'mine',
#   '.',
#   'it',
#   'is',
#   'reported',
#   'on',
#   'my',
#   'credit',
#   'and',
#   'causing',
#   'issues',
#   '.',
#   'this',
#   'company',
#   'has',
#   'had',
#   'a',
#   'lawsuit',
#   'from',
#   'multiple',
#   'states',
#   'already',
#   'regarding',
#   'their',
#   'practices',
#   'and',
#   'I',
#   'would',
#   'like',
#   'this',
#   'removed',
#   'from',
#   'my',
#   'credit',
#   'due',
#   'to',
#   'them',
#   'unable',
#   'to',
#   'prove',
#   'the',
#   'debt',
#   'is',
#   'legitimate',
#   '.'],
#  ['I',
#   'called',
#   'XXXX',
#   'XXXX',
#   'to',
#   'see',
#   'why',
#   'I',
#   'was',
#   'being',
#   'put',
#   'into',
#   'collection.XXXX',
#   'XXXX',
#   'told',
#   'me',
#   'it',
#   'was',
#   'for',
#   'non',
#   'returned',
#   'equipment.i',
#   'had',
#   'returned',
#   'this',
#   'equipment.erc',
#   'is',
#   'the',
#   'collection',
#   'agency',
#   'I',
#   'contacted',
#   'them',
#   'to',
#   'let',
#   'them',
#   'know',
#   'I',
#   'had',
#   'returned',
#   'the',
#   'equipment',
#   'and',
#   'they',
#   'said',
#   'there',
#   'was',
#   'XXXX',
#   'dollar',
#   'late',
#   'return',
#   'fee',
#   'I',
#   'have',
#   'not',
#   'seen',
#   'a',
#   'contract',
#   'with',
#   'this',
#   'on',
#   'it',
#   'with',
#   'my',
#   'signature.this',
#   'is',
#   'an',
#   'added',
#   'fee',
#   'that',
#   'I',
#   'need',
#   'a',
#   'copy',
#   'of',
#   'the',
#   'contract',
#   'that',
#   'states',
#   'this.the',
#   'man',
#   'at',
#   'erc',
#   'said',
#   'if',
#   'I',
#   'do',
#   "n't",
#   'pay',
#   'he',
#   'will',
#   'report',
#   'to',
#   'the',
#   'credit',
#   'beaureas.i',
#   'informed',
#   'him',
#   'this',
#   'was',
#   'a',
#   'violation',
#   'of',
#   'frca',
#   'rules',
#   'and',
#   'I',
#   'was',
#   'contacting',
#   'the',
#   'cfpb.he',
#   'said',
#   'it',
#   'could',
#   'be',
#   'resolved',
#   'if',
#   'I',
#   'payed',
#   'him',
#   'today',
#   'or',
#   'he',
#   'would',
#   'report',
#   'to',
#   'the',
#   'credit',
#   'beareaus.this',
#   'man',
#   'was',
#   'rude',
#   'and',
#   'abusive.under',
#   'frca',
#   'rules',
#   'he',
#   'can',
#   'not',
#   'report',
#   'to',
#   'the',
#   'credit',
#   'beareaus',
#   'while',
#   'this',
#   'is',
#   'disputed.he',
#   'needs',
#   'to',
#   'be',
#   'held',
#   'responsible',
#   'for',
#   'his',
#   'behaviors',
#   'this',
#   'was',
#   'all',
#   'on',
#   'a',
#   'recorded',
#   'line',
#   '.'],
#  ['Douglas',
#   'Chancellor',
#   'Meyer',
#   'entered',
#   'information',
#   'on',
#   'the',
#   'XXXX',
#   'Credit',
#   'Bereau',
#   'with',
#   'fradulent',
#   'and',
#   'falsified',
#   'information',
#   '.',
#   'The',
#   'date',
#   'of',
#   'orginal',
#   'diliquency',
#   'was',
#   'noted',
#   'as',
#   'XX/XX/2018',
#   '.',
#   'The',
#   'original',
#   'loan',
#   'was',
#   'from',
#   'XXXX',
#   '.',
#   'The',
#   'loan',
#   'went',
#   'diliquent',
#   'more',
#   'than',
#   '7',
#   'years',
#   'ago',
#   '.',
#   'XXXX',
#   'XXXX',
#   'is',
#   'attempting',
#   'to',
#   're-age',
#   'the',
#   'loan',
#   'in',
#   'violation',
#   'of',
#   'the',
#   'Fair',
#   'Credit',
#   'Reporting',
#   'Act',
#   '.',
#   'No',
#   'notice',
#   'of',
#   'dispute',
#   'was',
#   'furnished',
#   'to',
#   'me',
#   '.',
#   'I',
#   'contacted',
#   'XXXX',
#   'in',
#   'XX/XX/2018',
#   'to',
#   'dispute',
#   'the',
#   'information',
#   ',',
#   'also',
#   'on',
#   'XX/XX/XXXX',
#   'and',
#   'XX/XX/2018',
#   '.'],
#  ['I',
#   'have',
#   'some',
#   'adverse',
#   'information',
#   'on',
#   'my',
#   'credit',
#   'report',
#   'from',
#   'a',
#   'dentist',
#   'office',
#   'that',
#   'did',
#   'work',
#   'for',
#   'me',
#   'and',
#   'my',
#   'insurance',
#   'company',
#   'and',
#   'I',
#   'paid',
#   'what',
#   'was',
#   'owed',
#   'back',
#   'in',
#   'XXXX',
#   '.',
#   'I',
#   'was',
#   'just',
#   'made',
#   'aware',
#   'of',
#   'the',
#   'adverse',
#   'info',
#   'on',
#   'the',
#   'report',
#   'on',
#   'XXXX',
#   'XXXX',
#   ',',
#   'XXXX',
#   'and',
#   'immediately',
#   'called',
#   'the',
#   'company',
#   'Capital',
#   'Accounts',
#   '(',
#   'collection',
#   'agency',
#   ')',
#   'to',
#   'dispute',
#   ',',
#   'spoke',
#   'with',
#   'supervisor',
#   ',',
#   'XXXX',
#   'and',
#   'started',
#   'the',
#   'dispute',
#   'process',
#   '.',
#   'On',
#   'XXXX',
#   'XXXX',
#   ',',
#   'XXXX',
#   'I',
#   'called',
#   'to',
#   'follow',
#   'up',
#   'and',
#   'XXXX',
#   'said',
#   'the',
#   'dispute',
#   'had',
#   'been',
#   'filed',
#   'a',
#   'couple',
#   'of',
#   'weeks',
#   'ago',
#   'and',
#   'they',
#   'were',
#   'waiting',
#   'for',
#   'the',
#   'dentist',
#   'office',
#   'to',
#   'respond',
#   'and',
#   'he',
#   'could',
#   "n't",
#   'help',
#   'me',
#   'further',
#   ',',
#   'I',
#   'needed',
#   'to',
#   'wait',
#   'for',
#   'XXXX',
#   'to',
#   'call',
#   'me',
#   'back',
#   'in',
#   '2',
#   'hours',
#   'to',
#   'answer',
#   'any',
#   'other',
#   'questions',
#   '.',
#   'XXXX',
#   'never',
#   'called',
#   'me',
#   'back',
#   '.',
#   'I',
#   'called',
#   'back',
#   '24',
#   'hours',
#   'later',
#   'and',
#   'XXXX',
#   'said',
#   'this',
#   'has',
#   'been',
#   'going',
#   'on',
#   'since',
#   'XXXX',
#   'I',
#   'do',
#   "n't",
#   'need',
#   'to',
#   'discuss',
#   'anything',
#   'with',
#   'you',
#   'and',
#   'immediately',
#   'hung',
#   'up',
#   'on',
#   'me',
#   '.',
#   'I',
#   'called',
#   'back',
#   'an',
#   'hour',
#   'later',
#   'and',
#   'was',
#   'told',
#   'by',
#   'XXXX',
#   'that',
#   'I',
#   'needed',
#   'to',
#   'speak',
#   'with',
#   'XXXX',
#   'and',
#   'he',
#   "'d",
#   'call',
#   'me',
#   'back',
#   ',',
#   'still',
#   'have',
#   "n't",
#   'heard',
#   'from',
#   'XXXX',
#   '.',
#   'I',
#   'called',
#   'today',
#   ',',
#   'XXXX',
#   'XXXX',
#   ',',
#   'XXXX',
#   'and',
#   'spoke',
#   'with',
#   'XXXX',
#   'again',
#   'and',
#   'he',
#   'said',
#   'if',
#   'XXXX',
#   'did',
#   "n't",
#   'call',
#   'me',
#   'back',
#   'then',
#   'he',
#   'does',
#   "n't",
#   'know',
#   'what',
#   'to',
#   'tell',
#   'me',
#   '.',
#   'I',
#   'immediately',
#   'ended',
#   'the',
#   'call',
#   'because',
#   'this',
#   'does',
#   'not',
#   'seem',
#   'legit',
#   '.',
#   'In',
#   'addition',
#   ',',
#   'I',
#   'sent',
#   'a',
#   'letter',
#   'overnight',
#   'to',
#   'the',
#   'address',
#   'I',
#   'received',
#   'from',
#   'XXXX',
#   'on',
#   'XXXX',
#   'XXXX',
#   ',',
#   'XXXX',
#   'asking',
#   'to',
#   'resolve',
#   'this',
#   'matter',
#   ',',
#   'address',
#   'P.O',
#   '.',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   ',',
#   'TN',
#   'XXXX',
#   '.',
#   'Please',
#   'help',
#   'me',
#   'resolve',
#   'this',
#   'matter',
#   'so',
#   'I',
#   'can',
#   'move',
#   'on',
#   '.',
#   'Thank',
#   'you',
#   ',',
#   'XXXX',
#   'XXXX',
#   'XXXX'],
#  ['Bank',
#   'of',
#   'America',
#   'has',
#   'called',
#   '50',
#   'times',
#   'in',
#   'the',
#   'past',
#   '30',
#   'minutes',
#   'on',
#   'XXXX-17',
#   '.',
#   'I',
#   'am',
#   'at',
#   'work',
#   'and',
#   'they',
#   'did',
#   'leave',
#   'one',
#   'message',
#   'on',
#   'my',
#   'cell',
#   'phone',
#   '.',
#   'I',
#   'pay',
#   'this',
#   'bill',
#   'every',
#   'month',
#   'I',
#   'am',
#   'not',
#   'behind',
#   '.',
#   'It',
#   'was',
#   'charged',
#   'off',
#   ',',
#   'but',
#   'in',
#   'agreement',
#   'to',
#   'pay',
#   '10',
#   '%',
#   'of',
#   'the',
#   'balance',
#   'each',
#   'month',
#   'and',
#   'I',
#   'do',
#   'just',
#   'that',
#   '.',
#   'There',
#   'is',
#   'no',
#   'need',
#   'to',
#   'call',
#   'me',
#   '50',
#   'plus',
#   'times',
#   'in',
#   'a',
#   'row',
#   '.',
#   'I',
#   'blocked',
#   'their',
#   'call',
#   'just',
#   'so',
#   'my',
#   'phone',
#   'would',
#   'stop',
#   'buzzing',
#   'since',
#   'they',
#   'call',
#   'every',
#   '20',
#   'seconds',
#   '.'],
#  ['My',
#   'loan',
#   'debt',
#   'is',
#   'zero',
#   '.',
#   'I',
#   "'ve",
#   'received',
#   'all',
#   'letters',
#   'stating',
#   'this',
#   'and',
#   'I',
#   "'m",
#   'out',
#   'of',
#   'default',
#   'status',
#   '.',
#   'I',
#   "'m",
#   'beginning',
#   'college',
#   'at',
#   'University',
#   'XXXX',
#   'next',
#   'week',
#   'and',
#   'this',
#   'negative',
#   'impact',
#   'on',
#   'my',
#   'financial',
#   'aid',
#   'is',
#   'Ludacris',
#   '.',
#   'I',
#   'have',
#   'proof',
#   'all',
#   'loans',
#   'are',
#   'not',
#   'default',
#   'or',
#   'have',
#   'a',
#   'balance',
#   '.',
#   'They',
#   'harass',
#   'with',
#   'calls',
#   'even',
#   'though',
#   'I',
#   'owe',
#   'nothing',
#   'I',
#   "'m",
#   'going',
#   'to',
#   'sue',
#   'if',
#   'I',
#   'have',
#   'to',
#   '.',
#   'I',
#   'want',
#   'that',
#   'negative',
#   'impact',
#   'information',
#   'removed',
#   'asap',
#   'my',
#   'credit',
#   'is',
#   'suffering',
#   'because',
#   'of',
#   'these',
#   'greedy',
#   'collection',
#   'agencies',
#   'and',
#   'I',
#   'wo',
#   "n't",
#   'stand',
#   'for',
#   'it',
#   '.'],
#  ['During',
#   'XX/XX/XXXX-XX/XX/XXXX',
#   'I',
#   'lost',
#   'my',
#   'job',
#   'and',
#   'was',
#   'going',
#   'through',
#   'severe',
#   'financial',
#   'hardship',
#   '.',
#   'I',
#   'filed',
#   'a',
#   'financial',
#   'hardship',
#   'letter',
#   'around',
#   'XX/XX/XXXX',
#   'and',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'acknowledged',
#   'my',
#   'financial',
#   'hardship',
#   'and',
#   'restructured',
#   'my',
#   'loan',
#   'for',
#   'me',
#   'to',
#   'make',
#   'my',
#   'payments',
#   'lower',
#   '.',
#   'I',
#   'have',
#   'been',
#   'on',
#   'time',
#   'with',
#   'payments',
#   'every',
#   'month',
#   'since',
#   'then',
#   ',',
#   'up',
#   'until',
#   'and',
#   'including',
#   'this',
#   'month',
#   'of',
#   'XX/XX/XXXX',
#   '.',
#   'As',
#   'of',
#   'XX/XX/XXXX',
#   ',',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'claims',
#   'they',
#   'have',
#   'no',
#   'power',
#   'to',
#   'remove',
#   'the',
#   'late',
#   'payments',
#   'due',
#   'to',
#   'financial',
#   'hardship',
#   ',',
#   'and',
#   'said',
#   'I',
#   'could',
#   'file',
#   'a',
#   'complaint',
#   'or',
#   'converse',
#   'with',
#   'the',
#   'credit',
#   'bureaus',
#   'to',
#   'have',
#   'this',
#   'unfortunate',
#   'mistake',
#   'removed',
#   'from',
#   'my',
#   'report',
#   '.'],
#  ['I',
#   'received',
#   'a',
#   'credit',
#   'report',
#   'from',
#   'Experian',
#   'regarding',
#   'a',
#   'previous',
#   'complaint',
#   'on',
#   'XX/XX/XXXX',
#   ',',
#   'Dispute',
#   'Results',
#   'Report',
#   '#',
#   'XXXX',
#   '.',
#   'It',
#   'says',
#   'to',
#   'assist',
#   'you',
#   'in',
#   'understanding',
#   'summary',
#   ',',
#   'we',
#   'have',
#   'provided',
#   'additional',
#   'information',
#   'that',
#   'relates',
#   'directly',
#   'to',
#   'items',
#   'on',
#   'your',
#   'personal',
#   'credit',
#   'report',
#   '.',
#   'PLEASE',
#   'REFER',
#   'TO',
#   'YOUR',
#   'CREDIT',
#   'REPORT',
#   'FOR',
#   'UPDATE',
#   '.',
#   'THERE',
#   'WAS',
#   'NO',
#   'UPDATE',
#   '.',
#   'They',
#   'do',
#   "n't",
#   'explain',
#   'what',
#   'they',
#   'call',
#   'a',
#   'FICO',
#   'Score',
#   '8',
#   'as',
#   'to',
#   'why',
#   'it',
#   'dropped',
#   '62',
#   'points',
#   '.',
#   'They',
#   'quote',
#   'to',
#   'Section',
#   '611',
#   '(',
#   'a',
#   ')',
#   '(',
#   '3',
#   ')',
#   '(',
#   'A',
#   ')',
#   'of',
#   'the',
#   'Fair',
#   'Credit',
#   'Reporting',
#   'Act',
#   ',',
#   'we',
#   'were',
#   'unable',
#   'to',
#   'honor',
#   'your',
#   'request',
#   'or',
#   'a',
#   'portion',
#   'of',
#   'it',
#   'based',
#   'on',
#   'the',
#   'limited',
#   'time',
#   'amount',
#   'of',
#   'your',
#   'information',
#   'regarding',
#   'dispute',
#   '.',
#   'This',
#   'dispute',
#   'was',
#   'made',
#   'on',
#   'XX/XX/XXXX',
#   ',',
#   'and',
#   'dispute',
#   'done',
#   'on',
#   'XX/XX/XXXX',
#   '.',
#   'That',
#   'is',
#   'not',
#   'what',
#   'they',
#   'said',
#   'in',
#   'the',
#   'reponse',
#   'to',
#   'my',
#   'CFPB',
#   'Complaint',
#   '.',
#   'On',
#   'my',
#   'credit',
#   'report',
#   'they',
#   'are',
#   'allowing',
#   'XXXX',
#   'XXXX',
#   'under',
#   'Status',
#   'Foreclosed',
#   '.',
#   'This',
#   'account',
#   'is',
#   'scheduled',
#   'to',
#   'continue',
#   'on',
#   'record',
#   'until',
#   'XX/XX/XXXX',
#   '.',
#   'They',
#   'are',
#   'allowing',
#   'XXXX',
#   'XXXX',
#   "'s",
#   'statement',
#   'remain',
#   'on',
#   'my',
#   'report',
#   'that',
#   'this',
#   'account',
#   'is',
#   'to',
#   'continue',
#   'XX/XX/XXXX',
#   'when',
#   'it',
#   'does',
#   "n't",
#   'match',
#   'their',
#   'payment',
#   'history',
#   '.',
#   'This',
#   'item',
#   'was',
#   'was',
#   'updated',
#   'of',
#   'your',
#   'dispute',
#   'in',
#   'XX/XX/XXXX',
#   ',',
#   'again',
#   'no',
#   'update',
#   '.',
#   'As',
#   'a',
#   'consumer',
#   'on',
#   'a',
#   'foreclosed',
#   'property',
#   'the',
#   'date',
#   'starts',
#   'as',
#   'of',
#   'the',
#   'the',
#   'first',
#   'deliquency',
#   'date',
#   'and',
#   'stays',
#   'on',
#   'your',
#   'credit',
#   'report',
#   'for',
#   '7',
#   'years',
#   '.',
#   'My',
#   'first',
#   'deliquency',
#   'date',
#   'was',
#   'XX/XX/XXXX',
#   'which',
#   'shows',
#   'on',
#   'XXXX',
#   'and',
#   'XXXX',
#   'and',
#   'should',
#   'be',
#   'removed',
#   'on',
#   'XX/XX/XXXX',
#   '.',
#   'You',
#   'as',
#   'a',
#   'credit',
#   'reporting',
#   'agency',
#   'that',
#   'see',
#   "'s",
#   'my',
#   'credit',
#   'report',
#   'that',
#   'XXXX',
#   'XXXX',
#   'will',
#   'remove',
#   'the',
#   'foreclosure',
#   'in',
#   'XX/XX/XXXX',
#   ',',
#   'which',
#   'is',
#   'not',
#   'true',
#   '.',
#   'I',
#   'am',
#   'tired',
#   'of',
#   'fighting',
#   'with',
#   'Experian',
#   'and',
#   'their',
#   'dropping',
#   'my',
#   'credit',
#   'score',
#   'by',
#   '62',
#   'points',
#   '.',
#   'Their',
#   'customer',
#   'service',
#   'reps',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'their',
#   'talking',
#   'about',
#   'and',
#   'they',
#   'are',
#   'rude',
#   'compared',
#   'to',
#   'the',
#   'other',
#   'bureaus',
#   '.',
#   'You',
#   'as',
#   'a',
#   'credit',
#   'bureau',
#   'reporting',
#   'agency',
#   'are',
#   'the',
#   'worst',
#   'for',
#   'customer',
#   'service',
#   '.',
#   'I',
#   'may',
#   'have',
#   'difficulty',
#   'speaking',
#   'with',
#   'XXXX',
#   'and',
#   'XXXX',
#   'but',
#   'they',
#   'are',
#   'polite',
#   '.',
#   'I',
#   'have',
#   'my',
#   'foreclosure',
#   'coming',
#   'off',
#   'of',
#   'Experian',
#   'XX/XX/XXXX',
#   ',',
#   'XXXX',
#   'XX/XX/XXXX',
#   ',',
#   'and',
#   'XXXX',
#   'XX/XX/XXXX',
#   '.',
#   'So',
#   'XXXX',
#   'XXXX',
#   'reports',
#   'the',
#   'wrong',
#   'information',
#   'and',
#   'the',
#   'credit',
#   'bureaus',
#   'are',
#   'letting',
#   'them',
#   'report',
#   'the',
#   'wrong',
#   'information',
#   '.',
#   'Again',
#   'I',
#   'never',
#   'made',
#   'a',
#   'payment',
#   'in',
#   'XX/XX/XXXX',
#   'and',
#   'I',
#   'want',
#   'the',
#   'payment',
#   'of',
#   'XX/XX/XXXX',
#   'removed',
#   '.',
#   'I',
#   'want',
#   'you',
#   'to',
#   'see',
#   'what',
#   'they',
#   'were',
#   'reporting',
#   'to',
#   'XXXX',
#   'which',
#   'XXXX',
#   'XXXX',
#   'f/n/a',
#   'XXXX',
#   'XXXX',
#   'XXXX',
#   'changed',
#   'when',
#   'they',
#   'took',
#   'over',
#   'in',
#   'XXXX',
#   '.',
#   'Now',
#   'see',
#   'the',
#   'company',
#   'I',
#   'am',
#   'fighting',
#   'to',
#   'make',
#   'them',
#   'get',
#   'my',
#   'credit',
#   'reports',
#   'right',
#   'to',
#   'all',
#   'credit',
#   'bureaus',
#   '!'],
#  ['EQUIFAX',
#   'listed',
#   'three',
#   'fraudulent',
#   'hard',
#   'inquiries',
#   'which',
#   'they',
#   'are',
#   'unwilling',
#   'to',
#   'remove',
#   '(',
#   'even',
#   'with',
#   'proof',
#   ')',
#   'and',
#   'that',
#   'the',
#   'other',
#   'credit',
#   'agencies',
#   'do',
#   'not',
#   'report',
#   '.',
#   'Fraud',
#   'inquiries',
#   'on',
#   'EQUIFAX',
#   'report',
#   'are',
#   ':',
#   'XXXXXXXX',
#   'XXXX',
#   ',',
#   'XX/XX/XXXX',
#   ';',
#   'XXXX',
#   'XXXX',
#   ',',
#   'XX/XX/XXXX',
#   ';',
#   'XXXX',
#   'XXXX/XXXX',
#   ',',
#   'XX/XX/XXXX',
#   '.',
#   'I',
#   'received',
#   'documentation',
#   'from',
#   'XXXX',
#   'and',
#   'XXXX',
#   'that',
#   'these',
#   'were',
#   'fraud',
#   'attempts',
#   'to',
#   'open',
#   'credit',
#   '(',
#   'I',
#   'do',
#   'not',
#   'recognize',
#   'nor',
#   'authorized',
#   ')',
#   'and',
#   'no',
#   'accounts',
#   'were',
#   'opened',
#   '.',
#   'I',
#   'submitted',
#   'documentation',
#   'to',
#   'EQUIFAX',
#   'and',
#   'their',
#   'investigation',
#   'simply',
#   'states',
#   '``',
#   'these',
#   'inquiries',
#   'are',
#   'factual',
#   '``',
#   '.',
#   'Today',
#   '(',
#   'XX/XX/XXXX',
#   ')',
#   'I',
#   'received',
#   'an',
#   'alert',
#   'for',
#   'another',
#   'hard',
#   'inquiry',
#   'on',
#   'EQUIFAX',
#   'from',
#   'XXXX',
#   'XXXX/XXXX',
#   'for',
#   'a',
#   'fraud',
#   'attempt',
#   '(',
#   'confirmed',
#   'with',
#   'XXXX',
#   ',',
#   'agent',
#   '#',
#   'XXXX',
#   'in',
#   'XXXXXXXX',
#   'XXXX',
#   'Fraud',
#   'Dept',
#   ')',
#   '.',
#   'This',
#   'is',
#   'another',
#   'fraud',
#   'attempt',
#   'and',
#   'EQUIFAX',
#   'is',
#   'unwilling',
#   'to',
#   'remove',
#   'these',
#   'incorrect/fraud',
#   'hard',
#   'inquiries',
#   'from',
#   'my',
#   'report',
#   '.',
#   'My',
#   'credit',
#   'score',
#   'is',
#   'suffering',
#   'with',
#   'EQUIFAX',
#   '.',
#   'I',
#   'will',
#   'be',
#   'making',
#   'a',
#   'major',
#   'financial',
#   'purchase',
#   'soon',
#   'and',
#   'their',
#   'unwillingness',
#   'to',
#   'remove',
#   'the',
#   'hard',
#   'inquiries',
#   'on',
#   'my',
#   'file',
#   'will',
#   'cost',
#   'me',
#   'a',
#   'higher',
#   'interest',
#   'rate',
#   '(',
#   'EQUIFAX',
#   'MUST',
#   'FIX',
#   'THIS',
#   'IMMEDIATELY',
#   '-',
#   'PLEASE',
#   'HELP',
#   ')',
#   '.']]

# %%
words = [item for sublist in words for item in sublist]

# %%
words = [x.lower() for x in words]

# %%
words
# Out:
# ['when',
#  'my',
#  'loan',
#  'was',
#  'switched',
#  'over',
#  'to',
#  'navient',
#  'i',
#  'was',
#  'never',
#  'told',
#  'that',
#  'i',
#  'had',
#  'a',
#  'deliquint',
#  'balance',
#  'because',
#  'with',
#  'xxxx',
#  'i',
#  'did',
#  'not',
#  '.',
#  'when',
#  'going',
#  'to',
#  'purchase',
#  'a',
#  'vehicle',
#  'i',
#  'discovered',
#  'my',
#  'credit',
#  'score',
#  'had',
#  'been',
#  'dropped',
#  'from',
#  'the',
#  'xxxx',
#  'into',
#  'the',
#  'xxxx',
#  '.',
#  'i',
#  'have',
#  'been',
#  'faithful',
#  'at',
#  'paying',
#  'my',
#  'student',
#  'loan',
#  '.',
#  'i',
#  'was',
#  'told',
#  'that',
#  'navient',
#  'was',
#  'the',
#  'company',
#  'i',
#  'had',
#  'delinquency',
#  'with',
#  '.',
#  'i',
#  'contacted',
#  'navient',
#  'to',
#  'resolve',
#  'this',
#  'issue',
#  'you',
#  'and',
#  'kept',
#  'being',
#  'told',
#  'to',
#  'just',
#  'contact',
#  'the',
#  'credit',
#  'bureaus',
#  'and',
#  'expalin',
#  'the',
#  'situation',
#  'and',
#  'maybe',
#  'they',
#  'could',
#  'help',
#  'me',
#  '.',
#  'i',
#  'was',
#  'so',
#  'angry',
#  'that',
#  'i',
#  'just',
#  'hurried',
#  'and',
#  'paid',
#  'the',
#  'balance',
#  'off',
#  'and',
#  'then',
#  'after',
#  'tried',
#  'to',
#  'dispute',
#  'the',
#  'delinquency',
#  'with',
#  'the',
#  'credit',
#  'bureaus',
#  '.',
#  'i',
#  'have',
#  'had',
#  'so',
#  'much',
#  'trouble',
#  'bringing',
#  'my',
#  'credit',
#  'score',
#  'back',
#  'up',
#  '.',
#  'i',
#  'tried',
#  'to',
#  'sign',
#  'up',
#  'for',
#  'a',
#  'spending',
#  'monitoring',
#  'program',
#  'and',
#  'capital',
#  'one',
#  'will',
#  'not',
#  'let',
#  'me',
#  'access',
#  'my',
#  'account',
#  'through',
#  'them',
#  'my',
#  'mortgage',
#  'is',
#  'with',
#  'bb',
#  '&',
#  't',
#  'bank',
#  ',',
#  'recently',
#  'i',
#  'have',
#  'been',
#  'investigating',
#  'ways',
#  'to',
#  'pay',
#  'down',
#  'my',
#  'mortgage',
#  'faster',
#  'and',
#  'i',
#  'came',
#  'across',
#  'biweekly',
#  'mortgage',
#  'calculator',
#  'on',
#  'bb',
#  '&',
#  't',
#  "'s",
#  'website',
#  '.',
#  'it',
#  "'s",
#  'a',
#  'nice',
#  ',',
#  'easy',
#  'to',
#  'use',
#  'calculator',
#  'that',
#  'you',
#  'plug',
#  'in',
#  'your',
#  'interest',
#  'rate',
#  ',',
#  'mortgage',
#  'amount',
#  ',',
#  'mortgage',
#  'term',
#  ',',
#  'and',
#  'payment',
#  'type',
#  'and',
#  'it',
#  'calculates',
#  'your',
#  'accelerated',
#  'bi-weekly',
#  'payment',
#  'for',
#  'you',
#  'and',
#  'shows',
#  'you',
#  'how',
#  'much',
#  'quicker',
#  'you',
#  'can',
#  'pay',
#  'down',
#  'your',
#  'loan',
#  '.',
#  'ours',
#  'figured',
#  'out',
#  'to',
#  'pay',
#  'off',
#  'a',
#  '30',
#  'year',
#  'mortgage',
#  'in',
#  '26.4',
#  'years',
#  '...',
#  'quite',
#  'a',
#  'savings',
#  '!',
#  'i',
#  'called',
#  'bb',
#  '&',
#  't',
#  "'s",
#  'customer',
#  'service',
#  'number',
#  'to',
#  'inquire',
#  'how',
#  'i',
#  'get',
#  'set',
#  'up',
#  'on',
#  'this',
#  'payment',
#  'plan',
#  '.',
#  'i',
#  'was',
#  'told',
#  'they',
#  'do',
#  'not',
#  'offer',
#  'that',
#  'type',
#  'of',
#  'payment',
#  'plan',
#  ',',
#  'but',
#  'i',
#  'could',
#  'send',
#  'in',
#  'my',
#  'payments',
#  'bi-weekly',
#  'but',
#  'it',
#  'would',
#  'not',
#  'be',
#  'applied',
#  'until',
#  'the',
#  'full',
#  'amount',
#  'was',
#  'received',
#  '.',
#  '(',
#  'the',
#  'money',
#  'would',
#  'sit',
#  'in',
#  'a',
#  '``',
#  'holding',
#  'account',
#  '``',
#  'until',
#  'the',
#  'full',
#  'payment',
#  'amount',
#  'was',
#  'collected',
#  ')',
#  '.',
#  'i',
#  'ended',
#  'up',
#  'calling',
#  'back',
#  'a',
#  'few',
#  'days',
#  'later',
#  'thinking',
#  'the',
#  'rep',
#  'i',
#  'was',
#  'talking',
#  'to',
#  'did',
#  "n't",
#  'understand',
#  'what',
#  'i',
#  'wanted',
#  'to',
#  'do',
#  'or',
#  'was',
#  'not',
#  'knowledgeable',
#  'of',
#  'this',
#  'program',
#  '.',
#  'i',
#  'got',
#  'the',
#  'same',
#  'answer',
#  '!',
#  'i',
#  'then',
#  'asked',
#  'for',
#  'the',
#  'corporate',
#  'bb',
#  '&',
#  't',
#  'office',
#  'number',
#  'where',
#  'i',
#  'could',
#  'speak',
#  'to',
#  'someone',
#  'that',
#  'was',
#  'knowledgeable',
#  'of',
#  'this',
#  'product',
#  '.',
#  'after',
#  '3',
#  'days',
#  'i',
#  'received',
#  'a',
#  'phone',
#  'call',
#  'back',
#  'from',
#  'a',
#  'corporate',
#  'manager',
#  'stating',
#  'they',
#  'do',
#  'not',
#  'offer',
#  'this',
#  'product',
#  ',',
#  'and',
#  'they',
#  'were',
#  '``',
#  'checking',
#  'into',
#  'why',
#  'this',
#  'is',
#  'on',
#  'their',
#  'website',
#  '``',
#  '.',
#  'she',
#  'stated',
#  'they',
#  'do',
#  'have',
#  'a',
#  'few',
#  'customers',
#  'that',
#  'make',
#  'bi-weekly',
#  'payments',
#  ',',
#  'but',
#  'they',
#  'no',
#  'longer',
#  'offer',
#  'this',
#  'service',
#  '.',
#  'i',
#  'do',
#  "n't",
#  'understand',
#  'how',
#  'they',
#  'can',
#  'have',
#  'this',
#  'active',
#  'link',
#  'on',
#  'their',
#  'website',
#  'under',
#  'their',
#  'financial',
#  'planning',
#  'center',
#  'tab',
#  'to',
#  'mislead',
#  'customers',
#  'when',
#  'all',
#  'they',
#  'say',
#  'is',
#  '``',
#  'i',
#  "'m",
#  'sorry',
#  ',',
#  'i',
#  'know',
#  'you',
#  "'re",
#  'upset',
#  'about',
#  'this',
#  '``',
#  'sounds',
#  'like',
#  'false',
#  'advertising',
#  'to',
#  'me',
#  '!',
#  'https',
#  ':',
#  '//www.bbt.com/xxxx',
#  'the',
#  'entire',
#  'lending',
#  'experience',
#  'with',
#  'citizens',
#  'bank',
#  'was',
#  'terrible',
#  '.',
#  'the',
#  'lender',
#  'kept',
#  'pushing',
#  'a',
#  'xxxx',
#  'arm',
#  ',',
#  'which',
#  'we',
#  'had',
#  'considered',
#  'initially',
#  'but',
#  'decided',
#  'to',
#  'go',
#  'with',
#  'a',
#  '30yr',
#  'fixed',
#  '.',
#  'when',
#  'we',
#  'received',
#  'the',
#  'closing',
#  'disclosure',
#  ',',
#  'it',
#  'was',
#  'a',
#  'xxxx',
#  'arm',
#  ',',
#  'we',
#  'immediately',
#  'requested',
#  'that',
#  'it',
#  'be',
#  'corrected',
#  'to',
#  'the',
#  '30yr',
#  'fixed',
#  'we',
#  'decided',
#  'upon',
#  'but',
#  'they',
#  'kept',
#  'delaying',
#  'and',
#  'saying',
#  'it',
#  'was',
#  'changed',
#  'but',
#  'would',
#  "n't",
#  'send',
#  'it',
#  'to',
#  'us',
#  '.',
#  'they',
#  'waited',
#  'until',
#  'the',
#  'next',
#  'day',
#  'and',
#  'then',
#  'tried',
#  'to',
#  'convince',
#  'us',
#  'to',
#  'waive',
#  'our',
#  'rights',
#  'so',
#  'it',
#  'would',
#  "n't",
#  'push',
#  'the',
#  'closing',
#  'date',
#  'due',
#  'to',
#  'the',
#  '3',
#  'day',
#  'clock',
#  'reset',
#  '.',
#  'this',
#  'seemed',
#  'very',
#  'intentional',
#  ',',
#  'like',
#  'it',
#  'was',
#  'something',
#  'they',
#  'often',
#  'do',
#  ',',
#  'because',
#  'they',
#  'sent',
#  'us',
#  'an',
#  'email',
#  'instructing',
#  'us',
#  'to',
#  'draft',
#  'a',
#  'letter',
#  ':',
#  '--',
#  '--',
#  'from',
#  'the',
#  'loan',
#  'officer',
#  ':',
#  'i',
#  'have',
#  'outlined',
#  'the',
#  'basis',
#  'of',
#  'the',
#  'letter',
#  'in',
#  'this',
#  'email',
#  '.',
#  'please',
#  'elaborate',
#  'on',
#  'why',
#  'you',
#  'wanted',
#  'the',
#  'product',
#  'changed',
#  'and',
#  'make',
#  'sure',
#  'to',
#  'include',
#  'your',
#  'contact',
#  'information',
#  'at',
#  'the',
#  'bottom',
#  'as',
#  'they',
#  'will',
#  'need',
#  'this.',
#  "''",
#  'to',
#  'whom',
#  'it',
#  'may',
#  'concern',
#  ',',
#  'this',
#  'letter',
#  'is',
#  'to',
#  'waive',
#  'my',
#  'right',
#  'to',
#  'review',
#  'the',
#  'new',
#  'closing',
#  'disclosure',
#  '3',
#  'business',
#  'days',
#  'prior',
#  'to',
#  'closing',
#  '.',
#  'i',
#  'must',
#  'close',
#  'on',
#  'the',
#  'property',
#  'at',
#  '(',
#  'property',
#  'address',
#  ')',
#  'or',
#  'i',
#  'face',
#  'financial',
#  'hardship',
#  'in',
#  'the',
#  'form',
#  'of',
#  'losing',
#  'my',
#  'earnest',
#  'money',
#  'deposit',
#  'and',
#  'property',
#  'falling',
#  'through',
#  '.',
#  'i',
#  'must',
#  'close',
#  'on',
#  'this',
#  'property',
#  'on',
#  'xxxx',
#  '.',
#  'there',
#  'is',
#  'substantial',
#  'expense',
#  'associated',
#  'with',
#  'my',
#  'drive',
#  'and',
#  'move',
#  'to',
#  '(',
#  'property',
#  'address',
#  ')',
#  'and',
#  'require',
#  'this',
#  'property',
#  'so',
#  'i',
#  'may',
#  'begin',
#  '(',
#  'new',
#  'job',
#  ')',
#  'on',
#  'time',
#  '.',
#  'in',
#  'addition',
#  'this',
#  'letter',
#  'is',
#  'to',
#  'address',
#  'the',
#  'change',
#  'in',
#  'rate',
#  'and',
#  'product',
#  '.',
#  'this',
#  'was',
#  'done',
#  'at',
#  'my',
#  'request',
#  ',',
#  'i',
#  'requested',
#  'a',
#  '30',
#  'year',
#  'fixed',
#  'rate',
#  'loan',
#  'that',
#  'increased',
#  'my',
#  'rate',
#  'to',
#  '(',
#  '%',
#  ')',
#  'and',
#  'increased',
#  'my',
#  'apr',
#  '.',
#  'i',
#  'decided',
#  'that',
#  'the',
#  '30',
#  'year',
#  'fixed',
#  'was',
#  'a',
#  'safe',
#  'option',
#  'to',
#  'avoid',
#  'the',
#  'market',
#  'causing',
#  'my',
#  'arm',
#  'rate',
#  'to',
#  'increase',
#  '.',
#  'i',
#  'felt',
#  'as',
#  'though',
#  'the',
#  'difference',
#  'in',
#  'payment',
#  'monthly',
#  'was',
#  'worth',
#  'the',
#  'security',
#  'of',
#  'having',
#  'a',
#  'fixed',
#  'rate',
#  'and',
#  'knowing',
#  'the',
#  'rate',
#  'could',
#  'not',
#  'increase',
#  '.',
#  'i',
#  'am',
#  'fully',
#  'aware',
#  'that',
#  'the',
#  'rate',
#  'and',
#  'apr',
#  'increased',
#  'and',
#  'am',
#  'fully',
#  'aware',
#  'of',
#  'the',
#  'difference',
#  'in',
#  'monthly',
#  'payment',
#  'however',
#  'i',
#  'still',
#  'wish',
#  'to',
#  'go',
#  'with',
#  'the',
#  '30',
#  'year',
#  'fixed',
#  'and',
#  'need',
#  'to',
#  'close',
#  'on',
#  'xxxx',
#  '.',
#  'my',
#  'contact',
#  'information',
#  'is',
#  'below',
#  'and',
#  'should',
#  'anyone',
#  'have',
#  'any',
#  'questions',
#  'please',
#  'do',
#  'not',
#  'hesitate',
#  'to',
#  'reach',
#  'out',
#  'to',
#  'me',
#  '.',
#  'i',
#  'look',
#  'forward',
#  'to',
#  'closing',
#  'my',
#  'loan.',
#  '``',
#  'please',
#  'make',
#  'sure',
#  'to',
#  'physically',
#  'sign',
#  'and',
#  'date',
#  'this',
#  'at',
#  'the',
#  'bottom',
#  'and',
#  'send',
#  'back',
#  'so',
#  'we',
#  'can',
#  'close',
#  'on',
#  'time',
#  '.',
#  'thanks',
#  '--',
#  '--',
#  'we',
#  'responded',
#  'with',
#  'this',
#  ':',
#  '``',
#  'we',
#  'do',
#  "n't",
#  'feel',
#  'comfortable',
#  'moving',
#  'forward',
#  'by',
#  'waving',
#  'our',
#  'rights',
#  'to',
#  'review',
#  'a',
#  'closing',
#  'disclosure',
#  '.',
#  'we',
#  'would',
#  'like',
#  'to',
#  'receive',
#  'the',
#  'corrected',
#  'closing',
#  'disclosure',
#  'for',
#  'the',
#  '30yr',
#  'fixed',
#  'including',
#  'the',
#  'corrected',
#  'deposit',
#  ...]

# %%
custom = stopwords.words("english")+list(punctuation)

# %%
words = [x for x in words if x not in custom]

# %%
custom
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
from collections import Counter

# %%
d = dict(Counter(words))

# %%
import operator

sorted_d = sorted(d.items(), key=operator.itemgetter(1), reverse=True)

# %%
sorted_d
# Out:
# [('xxxx', 378),
#  ('credit', 90),
#  ('account', 79),
#  ('``', 59),
#  ('report', 46),
#  ('xx/xx/xxxx', 44),
#  ("n't", 42),
#  ('bank', 26),
#  ('information', 26),
#  ('back', 24),
#  ('business', 24),
#  ('chase', 24),
#  ('company', 23),
#  ('debt', 23),
#  ('called', 21),
#  ('money', 21),
#  ('call', 21),
#  ('said', 21),
#  ('loan', 20),
#  ('pay', 20),
#  ('number', 20),
#  ('received', 20),
#  ('could', 19),
#  ('would', 19),
#  ('sent', 19),
#  ('told', 18),
#  ('get', 18),
#  ('asked', 18),
#  ('removed', 18),
#  ('times', 18),
#  ('phone', 17),
#  ('dispute', 16),
#  ("'s", 16),
#  ('amount', 16),
#  ('payment', 16),
#  ('still', 16),
#  ('open', 16),
#  ('name', 16),
#  ('reporting', 16),
#  ('contacted', 15),
#  ('time', 15),
#  ('date', 14),
#  ('deposit', 14),
#  ('accounts', 14),
#  ('file', 14),
#  ('closing', 13),
#  ('please', 13),
#  ('made', 13),
#  ('collection', 13),
#  ('equifax', 13),
#  ('...', 12),
#  ("'m", 12),
#  ('know', 12),
#  ('letter', 12),
#  ('also', 12),
#  ('going', 11),
#  ('score', 11),
#  ('make', 11),
#  ('need', 11),
#  ('right', 11),
#  ('experian', 11),
#  ('one', 10),
#  ('rate', 10),
#  ('requested', 10),
#  ('day', 10),
#  ('move', 10),
#  ('even', 10),
#  ('calls', 10),
#  ('want', 10),
#  ('balance', 9),
#  ('bureaus', 9),
#  ('help', 9),
#  ('financial', 9),
#  ('opened', 9),
#  ('complaint', 9),
#  ('card', 9),
#  ('remove', 9),
#  ('xx/xx/2018', 9),
#  ('branch', 9),
#  ('never', 8),
#  ('mortgage', 8),
#  ('interest', 8),
#  ('years', 8),
#  ('send', 8),
#  ('payments', 8),
#  ('days', 8),
#  ('office', 8),
#  ('checking', 8),
#  ('say', 8),
#  ('fixed', 8),
#  ('us', 8),
#  ('due', 8),
#  ('email', 8),
#  ('must', 8),
#  ('close', 8),
#  ('property', 8),
#  ('since', 8),
#  ('without', 8),
#  ('months', 8),
#  ('fraud', 8),
#  ('inquiry', 8),
#  ('2', 8),
#  ('asking', 8),
#  ('today', 8),
#  ('owe', 8),
#  ('see', 8),
#  ('way', 8),
#  ('personal', 8),
#  ('inquiries', 8),
#  ('put', 8),
#  ('suspicious', 8),
#  ('purchase', 7),
#  ('contact', 7),
#  ('paid', 7),
#  ('like', 7),
#  ('address', 7),
#  ('request', 7),
#  ('several', 7),
#  ('another', 7),
#  ('month', 7),
#  ('letters', 7),
#  ('fair', 7),
#  ('act', 7),
#  ('stop', 7),
#  ('unable', 7),
#  ('wi', 7),
#  ('funds', 7),
#  ('every', 7),
#  ('wrong', 7),
#  ('service', 6),
#  ('offer', 6),
#  ('3', 6),
#  ('decided', 6),
#  ('immediately', 6),
#  ('form', 6),
#  ('responded', 6),
#  ('feel', 6),
#  ('closed', 6),
#  ('agencies', 6),
#  ('fraudulent', 6),
#  ('check', 6),
#  ('past', 6),
#  ('item', 6),
#  ('thank', 6),
#  ('tell', 6),
#  ('problem', 6),
#  ('proof', 6),
#  ('continue', 6),
#  ('theft', 6),
#  ('response', 6),
#  ('late', 6),
#  ('transfer', 6),
#  ('able', 6),
#  ('settlement', 6),
#  ('needed', 6),
#  ('illinois', 6),
#  ('alert', 6),
#  ('hard', 6),
#  ('cash', 6),
#  ('charges', 6),
#  ('delinquent', 6),
#  ('agency', 6),
#  ('tried', 5),
#  ('use', 5),
#  ('type', 5),
#  ('30', 5),
#  ('year', 5),
#  ('customer', 5),
#  ('later', 5),
#  ('manager', 5),
#  ('stating', 5),
#  ('go', 5),
#  ('disclosure', 5),
#  ('sure', 5),
#  ('hardship', 5),
#  ('done', 5),
#  ('security', 5),
#  ('line', 5),
#  ('federal', 5),
#  ('bankruptcy', 5),
#  ('bureau', 5),
#  ('court', 5),
#  ('went', 5),
#  ('verified', 5),
#  ('showing', 5),
#  ('listed', 5),
#  ('well', 5),
#  ('keep', 5),
#  ('getting', 5),
#  ('refuse', 5),
#  ('different', 5),
#  ('turned', 5),
#  ('contract', 5),
#  ('provide', 5),
#  ('copy', 5),
#  ('old', 5),
#  ('identity', 5),
#  ('yet', 5),
#  ('filed', 5),
#  ('opted', 5),
#  ('activity', 5),
#  ('says', 5),
#  ('deleted', 5),
#  ('multiple', 5),
#  ('first', 5),
#  ('bills', 5),
#  ('resolve', 4),
#  ('much', 4),
#  ('sign', 4),
#  ('bb', 4),
#  ('plan', 4),
#  ('full', 4),
#  ('understand', 4),
#  ('speak', 4),
#  ('someone', 4),
#  ('product', 4),
#  ('changed', 4),
#  ('--', 4),
#  ('though', 4),
#  ('worth', 4),
#  ('however', 4),
#  ('already', 4),
#  ('signed', 4),
#  ('ach', 4),
#  ('debit', 4),
#  ('last', 4),
#  ('reports', 4),
#  ('victim', 4),
#  ('incorrect', 4),
#  ('5', 4),
#  ('6', 4),
#  ('written', 4),
#  ('verify', 4),
#  ('reported', 4),
#  ('writing', 4),
#  ('mail', 4),
#  ('practices', 4),
#  ('7', 4),
#  ('list', 4),
#  ('rude', 4),
#  ("'ve", 4),
#  ('equipment', 4),
#  ('attempt', 4),
#  ('resolved', 4),
#  ('consumer', 4),
#  ('signature', 4),
#  ('transferred', 4),
#  ('update', 4),
#  ('acceptance', 4),
#  ('corporation', 4),
#  ('waiting', 4),
#  ('p/', 4),
#  ('portfolio', 4),
#  ('recovery', 4),
#  ('validation', 4),
#  ('status', 4),
#  ('trying', 4),
#  ('regarding', 4),
#  ('hold', 4),
#  ('explain', 4),
#  ('around', 4),
#  ('ca', 4),
#  ('lost', 4),
#  ('responsible', 4),
#  ('dont', 4),
#  ('history', 4),
#  ('repeatedly', 4),
#  ('legal', 4),
#  ('fees', 4),
#  ('top', 4),
#  ('agreement', 4),
#  ('navient', 3),
#  ('vehicle', 3),
#  ('delinquency', 3),
#  ('kept', 3),
#  ('let', 3),
#  ('website', 3),
#  ('bi-weekly', 3),
#  ('set', 3),
#  ('calling', 3),
#  ('answer', 3),
#  ('customers', 3),
#  ('citizens', 3),
#  ('arm', 3),
#  ('considered', 3),
#  ('30yr', 3),
#  ('corrected', 3),
#  ('bottom', 3),
#  ('may', 3),
#  ('increased', 3),
#  ('causing', 3),
#  ('monthly', 3),
#  ('knowing', 3),
#  ('aware', 3),
#  ('receive', 3),
#  ('really', 3),
#  ('correct', 3),
#  ('charged', 3),
#  ('fighting', 3),
#  ('points', 3),
#  ('police', 3),
#  ('dropping', 3),
#  ('commission', 3),
#  ('disputing', 3),
#  ('give', 3),
#  ('life', 3),
#  ('matter', 3),
#  ('xxxx/xxxx/xxxx', 3),
#  ('people', 3),
#  ('looking', 3),
#  ('authorized', 3),
#  ('three', 3),
#  ('started', 3),
#  ('spoke', 3),
#  ('left', 3),
#  ('work', 3),
#  ('cell', 3),
#  ('fax', 3),
#  ('original', 3),
#  ('added', 3),
#  ('breach', 3),
#  ('mine', 3),
#  ('claim', 3),
#  ('gap', 3),
#  ('posted', 3),
#  ('2017', 3),
#  ('comenity', 3),
#  ('provided', 3),
#  ('violation', 3),
#  ('documentation', 3),
#  ('statement', 3),
#  ('funding', 3),
#  ('weeks', 3),
#  ('formerly', 3),
#  ('doors', 3),
#  ('happened', 3),
#  ('explained', 3),
#  ('soon', 3),
#  ('making', 3),
#  ('supposed', 3),
#  ('hours', 3),
#  ('placed', 3),
#  ('owner', 3),
#  ('leave', 3),
#  ('within', 3),
#  ('posting', 3),
#  ('data', 3),
#  ('impact', 3),
#  ('settle', 3),
#  ('bill', 3),
#  ('chapter', 3),
#  ('footage', 3),
#  ('xxxxxxxx', 3),
#  ('allowing', 3),
#  ('negative', 3),
#  ('states', 3),
#  ('returned', 3),
#  ('dropped', 2),
#  ('paying', 2),
#  ('student', 2),
#  ('maybe', 2),
#  ('bringing', 2),
#  ('program', 2),
#  ('capital', 2),
#  ('calculator', 2),
#  ('shows', 2),
#  ('savings', 2),
#  ('ended', 2),
#  ('rep', 2),
#  ('talking', 2),
#  ('wanted', 2),
#  ('knowledgeable', 2),
#  ('corporate', 2),
#  ('stated', 2),
#  ('longer', 2),
#  ('active', 2),
#  ('center', 2),
#  ('upset', 2),
#  ('https', 2),
#  ('entire', 2),
#  ('experience', 2),
#  ('waited', 2),
#  ('next', 2),
#  ('waive', 2),
#  ('rights', 2),
#  ('clock', 2),
#  ('reset', 2),
#  ('something', 2),
#  ('officer', 2),
#  ("''", 2),
#  ('concern', 2),
#  ('review', 2),
#  ('new', 2),
#  ('job', 2),
#  ('addition', 2),
#  ('change', 2),
#  ('apr', 2),
#  ('increase', 2),
#  ('difference', 2),
#  ('fully', 2),
#  ('anyone', 2),
#  ('questions', 2),
#  ('reach', 2),
#  ('forward', 2),
#  ('thanks', 2),
#  ('including', 2),
#  ('come', 2),
#  ('directly', 2),
#  ('forgotten', 2),
#  ('authorization', 2),
#  ('opening', 2),
#  ('find', 2),
#  ('significant', 2),
#  ('documents', 2),
#  ('appeared', 2),
#  ('tremendously', 2),
#  ('trade', 2),
#  ('inquires', 2),
#  ('issues', 2),
#  ('district', 2),
#  ('id', 2),
#  ('explaining', 2),
#  ('show', 2),
#  ('verification', 2),
#  ('info', 2),
#  ('attorney', 2),
#  ('caller', 2),
#  ('fcc', 2),
#  ('spoofed', 2),
#  ('representative', 2),
#  ('taken', 2),
#  ('per', 2),
#  ('gotten', 2),
#  ('person', 2),
#  ('take', 2),
#  ('speaking', 2),
#  ('connected', 2),
#  ('supervisor', 2),
#  ('message', 2),
#  ('apparently', 2),
#  ('wife', 2),
#  ('second', 2),
#  ('investigation', 2),
#  ('section', 2),
#  ('required', 2),
#  ('law', 2),
#  ('post', 2),
#  ('services', 2),
#  ('verifiable', 2),
#  ('mention', 2),
#  ('certified', 2),
#  ('thing', 2),
#  ('used', 2),
#  ('clearly', 2),
#  ('seen', 2),
#  ('bridgecrest', 2),
#  ('total', 2),
#  ('4.00', 2),
#  ('wanting', 2),
#  ('thier', 2),
#  ('high', 2),
#  ('visa', 2),
#  ('charge', 2),
#  ('sending', 2),
#  ('transunion/', 2),
#  ('sincerely', 2),
#  ('bearing', 2),
#  ('twice', 2),
#  ('validate', 2),
#  ('coinbase', 2),
#  ('inc', 2),
#  ('small', 2),
#  ('return', 2),
#  ('heard', 2),
#  ('known', 2),
#  ('motorcycles', 2),
#  ('revenue', 2),
#  ('2nd', 2),
#  ('friday', 2),
#  ('saturday', 2),
#  ('headed', 2),
#  ('unavailable', 2),
#  ('sabotaged', 2),
#  ('sensitive', 2),
#  ('cashiers', 2),
#  ('happen', 2),
#  ('process', 2),
#  ('bright', 2),
#  ('blue', 2),
#  ('jogging', 2),
#  ('suit', 2),
#  ('dream', 2),
#  ('greeted', 2),
#  ('teller', 2),
#  ('ok', 2),
#  ("ma'am", 2),
#  ('yes', 2),
#  ('fine', 2),
#  ('flag', 2),
#  ('continued', 2),
#  ('speaker', 2),
#  ('meet', 2),
#  ('wait', 2),
#  ('banker', 2),
#  ('hung', 2),
#  ('minutes', 2),
#  ('movers', 2),
#  ('buy', 2),
#  ('comes', 2),
#  ('yeah', 2),
#  ('ask', 2),
#  ('held', 2),
#  ('large', 2),
#  ('hands', 2),
#  ('scheduled', 2),
#  ('additional', 2),
#  ('cost', 2),
#  ('least', 2),
#  ('executive', 2),
#  ('nothing', 2),
#  ('caused', 2),
#  ('acknowledged', 2),
#  ('legitimate', 2),
#  ('actions', 2),
#  ('couple', 2),
#  ('duplicate', 2),
#  ('disputed', 2),
#  ('took', 2),
#  ('lower', 2),
#  ('contacting', 2),
#  ('tells', 2),
#  ('else', 2),
#  ('good', 2),
#  ('match', 2),
#  ('record', 2),
#  ('taking', 2),
#  ('action', 2),
#  ('department', 2),
#  ('numerous', 2),
#  ('submitted', 2),
#  ('creditor', 2),
#  ('continues', 2),
#  ('8', 2),
#  ('informed', 2),
#  ('learned', 2),
#  ('learning', 2),
#  ('legit', 2),
#  ('refused', 2),
#  ('incarcerated', 2),
#  ('detained', 2),
#  ('extra', 2),
#  ('detention', 2),
#  ('incarceration', 2),
#  ('respond', 2),
#  ('unacceptable', 2),
#  ('tired', 2),
#  ('related', 2),
#  ('xx/xx/18', 2),
#  ('refuses', 2),
#  ('recognize', 2),
#  ('notice', 2),
#  ('telling', 2),
#  ('havent', 2),
#  ('major', 2),
#  ('asset', 2),
#  ('retail', 2),
#  ('loans', 2),
#  ('seem', 2),
#  ('needs', 2),
#  ('add', 2),
#  ('class', 2),
#  ('associates', 2),
#  ('attempting', 2),
#  ('prove', 2),
#  ('fee', 2),
#  ('man', 2),
#  ('frca', 2),
#  ('rules', 2),
#  ('ago', 2),
#  ('adverse', 2),
#  ('dentist', 2),
#  ('50', 2),
#  ('default', 2),
#  ('suffering', 2),
#  ('62', 2),
#  ('foreclosed', 2),
#  ('deliquency', 2),
#  ('foreclosure', 2),
#  ('unwilling', 2),
#  ('xxxx/xxxx', 2),
#  ('switched', 1),
#  ('deliquint', 1),
#  ('discovered', 1),
#  ('faithful', 1),
#  ('issue', 1),
#  ('expalin', 1),
#  ('situation', 1),
#  ('angry', 1),
#  ('hurried', 1),
#  ('trouble', 1),
#  ('spending', 1),
#  ('monitoring', 1),
#  ('access', 1),
#  ('recently', 1),
#  ('investigating', 1),
#  ('ways', 1),
#  ('faster', 1),
#  ('came', 1),
#  ('across', 1),
#  ('biweekly', 1),
#  ('nice', 1),
#  ('easy', 1),
#  ('plug', 1),
#  ('term', 1),
#  ('calculates', 1),
#  ('accelerated', 1),
#  ('quicker', 1),
#  ('figured', 1),
#  ('26.4', 1),
#  ('quite', 1),
#  ('inquire', 1),
#  ('applied', 1),
#  ('sit', 1),
#  ('holding', 1),
#  ('collected', 1),
#  ('thinking', 1),
#  ('got', 1),
#  ('link', 1),
#  ('planning', 1),
#  ('tab', 1),
#  ('mislead', 1),
#  ('sorry', 1),
#  ("'re", 1),
#  ('sounds', 1),
#  ('false', 1),
#  ('advertising', 1),
#  ('//www.bbt.com/xxxx', 1),
#  ('lending', 1),
#  ('terrible', 1),
#  ('lender', 1),
#  ('pushing', 1),
#  ('initially', 1),
#  ('upon', 1),
#  ('delaying', 1),
#  ('saying', 1),
#  ('convince', 1),
#  ('push', 1),
#  ('seemed', 1),
#  ('intentional', 1),
#  ('often', 1),
#  ('instructing', 1),
#  ('draft', 1),
#  ('outlined', 1),
#  ('basis', 1),
#  ('elaborate', 1),
#  ('include', 1),
#  ('this.', 1),
#  ('prior', 1),
#  ('face', 1),
#  ('losing', 1),
#  ('earnest', 1),
#  ('falling', 1),
#  ('substantial', 1),
#  ('expense', 1),
#  ('associated', 1),
#  ('drive', 1),
#  ('require', 1),
#  ('begin', 1),
#  ('safe', 1),
#  ('option', 1),
#  ('avoid', 1),
#  ('market', 1),
#  ('felt', 1),
#  ('wish', 1),
#  ('hesitate', 1),
#  ('look', 1),
#  ('loan.', 1),
#  ('physically', 1),
#  ('comfortable', 1),
#  ('moving', 1),
#  ('waving', 1),
#  ('appreciate', 1),
#  ('tonight', 1),
#  ('pushed', 1),
#  ('expected.', 1),
#  ('finally', 1),
#  ('occasions', 1),
#  ('opportunity', 1),
#  ('desired', 1),
#  ('discount', 1),
#  ('primary', 1),
#  ('institution', 1),
#  ('dated', 1),
#  ('direct', 1),
#  ('.it', 1),
#  ('turns', 1),
#  ('husband', 1),
#  ('signatures', 1),
#  ('properly', 1),
#  ('gone', 1),
#  ('reviewed', 1),
#  ('reason', 1),
#  ('decrease', 1),
#  ('regards', 1),
#  ('necessary', 1),
#  ('affidavit', 1),
#  ('allowed', 1),
#  ('preparing', 1),
#  ('noticed', 1),
#  ('six', 1),
#  ('knowledge', 1),
#  ('ever', 1),
#  ('companies', 1),
#  ('solving', 1),
#  ('1.xxxx/xxxx', 1),
#  ('.national', 1),
#  ('cards/airlines', 1),
#  ('4.xxxx', 1),
#  ('2.xxxx/xxxx', 1),
#  ('3.xxxx', 1),
#  ('dozen', 1),
#  ('wrote', 1),
#  ('accurately', 1),
#  ('indicating', 1),
#  ('accurate', 1),
#  ('gets', 1),
#  ('method', 1),
#  ('effects', 1),
#  ('spoken', 1),
#  ('fit', 1),
#  ('complain', 1),
#  ('ignoring', 1),
#  ('fear', 1),
#  ('organization', 1),
#  ('general', 1),
#  ('etc', 1),
#  ('finance', 1),
#  ('llc', 1),
#  ('usually', 1),
#  ('absolutely', 1),
#  ('intent', 1),
#  ('collect', 1),
#  ('spoofing', 1),
#  ('illegal', 1),
#  ('communications', 1),
#  ('//www.fcc.gov/consumers/guides/spoofing-and-caller-id', 1),
#  ('insulted', 1),
#  ('harassed', 1),
#  ('curious', 1),
#  ('experienced', 1),
#  ('ar', 1),
#  ('resources', 1),
#  ('document', 1),
#  ('pick', 1),
#  ('35', 1),
#  ('considering', 1),
#  ('changing', 1),
#  ('harassment', 1),
#  ('outstanding', 1),
#  ('try', 1),
#  ('hang', 1),
#  ('laughing', 1),
#  ('paperwork', 1),
#  ('mailed', 1),
#  ('cease', 1),
#  ('desist', 1),
#  ('paperwork-they', 1),
#  ('giving', 1),
#  ('ones', 1),
#  ('renting', 1),
#  ('cr', 1),
#  ('correspondence', 1),
#  ('accounts.according', 1),
#  ('609', 1),
#  ('1', 1),
#  ('-through', 1),
#  ('physical', 1),
#  ('-any', 1),
#  ('otherwise', 1),
#  ('demand', 1),
#  ('failure', 1),
#  ('positively', 1),
#  ('hurt', 1),
#  ('ability', 1),
#  ('obtain', 1),
#  ('fcra', 1),
#  ('unverified', 1),
#  ('appears', 1),
#  ('un', 1),
#  ('rest', 1),
#  ('threat', 1),
#  ('involving', 1),
#  ('living', 1),
#  ('amazing', 1),
#  ('following', 1),
#  ('robbed', 1),
#  ('bullied', 1),
#  ('controlled', 1),
#  ('attempted', 1),
#  ('disputes', 1),
#  ('via', 1),
#  ('removal', 1),
#  ('alleged', 1),
#  ('scare', 1),
#  ('tactics', 1),
#  ('threaten', 1),
#  ('funny', 1),
#  ('fake', 1),
#  ('social', 1),
#  ('spelt', 1),
#  ('ssn', 1),
#  ('clear', 1),
#  ('ripping', 1),
#  ('belongs', 1),
#  ('insurrance', 1),
#  ('short', 1),
#  ('differance', 1),
#  ('lack', 1),
#  ('attention', 1),
#  ('financing', 1),
#  ('interst', 1),
#  ('rates', 1),
#  ('truthful', 1),
#  ('accumulated', 1),
#  ('simple', 1),
#  ('amout', 1),
#  ('vehicles', 1),
#  ('involve', 1),
#  ('accident', 1),
#  ('reasonable', 1),
#  ('explanation', 1),
#  ('charging', 1),
#  ('actually', 1),
#  ('la', 1),
#  ('dear', 1),
#  ('xxxx/', 1),
#  ('ftc', 1),
#  ('authorize', 1),
#  ('470.00', 1),
#  ('pursuant', 1),
#  ('compa', 1),
#  ('ny', 1),
#  ('failed', 1),
#  ('marked', 1),
#  ('agree', 1),
#  ('house', 1),
#  ('damage', 1),
#  ('fdcpa', 1),
#  ('807', 1),
#  ('15', 1),
#  ('usc', 1),
#  ('1962e', 1),
#  ('therefore', 1),
#  ('delete', 1),
#  ('entry', 1),
#  ('keeping', 1),
#  ('records', 1),
#  ('wire', 1),
#  ('usd', 1),
#  ('recipient', 1),
#  ('web', 1),
#  ('site', 1),
#  ('1st', 1),
#  ('reference', 1),
#  ('details', 1),
#  ('till', 1),
#  ('caseid', 1),
#  ('attaching', 1),
#  ('exchange', 1),
#  ('confirm', 1),
#  ('worked', 1),
#  ('relations', 1),
#  ('promised', 1),
#  ('diligently', 1),
#  ('promise', 1),
#  ('choice', 1),
#  ('33', 1),
#  ('collateral.our', 1),
#  ('thoughts', 1),
#  ('shortest', 1),
#  ('possible', 1),
#  ('tied', 1),
#  ('it.4', 1),
#  ('secure', 1),
#  ('complete', 1),
#  ('xxxxcashiers', 1),
#  ('checked', 1),
#  ('morning', 1),
#  ('successful', 1),
#  ('alone', 1),
#  ('prescheduled', 1),
#  ('vindictively', 1),
#  ('spite', 1),
#  ('chose', 1),
#  ('deposited', 1),
#  ('cleared', 1),
#  ('pieces', 1),
#  ('moved', 1),
#  ('away', 1),
#  ('5800.00', 1),
#  ('wearing', 1),
#  ('distinctive', 1),
#  ('description', 1),
#  ('dl', 1),
#  ('banks', 1),
#  ('eye', 1),
#  ('everything', 1),
#  ('pondered', 1),
#  ('attentiveness', 1),
#  ('note', 1),
#  ('sitting', 1),
#  ('cubicle', 1),
#  ('gaze', 1),
#  ('computer', 1),
#  ('interrogate', 1),
#  ('intentions', 1),
#  ('point', 1),
#  ('unaware', 1),
#  ('inaccessible', 1),
#  ('il', 1),
#  ('interrupted', 1),
#  ('king', 1),
#  ('preferred', 1),
#  ('patiently', 1),
#  ('6-7', 1),
#  ('anxious', 1),
#  ('technicians', 1),
#  ('friends', 1),
#  ('little', 1),
#  ('green', 1),
#  ('bag', 1),
#  ('desk', 1),
#  ('at.', 1),
#  ('almost', 1),
#  ('location', 1),
#  ('balling', 1),
#  ('literally', 1),
#  ('shaking', 1),
#  ('unless', 1),
#  ('internal', 1),
#  ('female', 1),
#  ('crying', 1),
#  ('cops', 1),
#  ('criminal', 1),
#  ('character', 1),
#  ('withdrawal', 1),
#  ('activity.', 1),
#  ('knew', 1),
#  ('available', 1),
#  ('secured', 1),
#  ('blood', 1),
#  ('costs', 1),
#  ('thousands', 1),
#  ('deposits', 1),
#  ('minute', 1),
#  ('rearranging', 1),
#  ('trucks', 1),
#  ('expenses', 1),
#  ('2+', 1),
#  ('delay', 1),
#  ('cards', 1),
#  ('degraded', 1),
#  ('sanity', 1),
#  ('struggling', 1),
#  ('quit', 1),
#  ('working', 1),
#  ('start', 1),
#  ('trusted', 1),
#  ('bad', 1),
#  ('decision', 1),
#  ('filing', 1),
#  ('locations', 1),
#  ('condones', 1),
#  ('behavior', 1),
#  ('equally', 1),
#  ('damages', 1),
#  ('referred', 1),
#  ('admitted', 1),
#  ('remedy', 1),
#  ('likely', 1),
#  ('absorb', 1),
#  ('mess', 1),
#  ('tapped', 1),
#  ('maxed', 1),
#  ('relationship', 1),
#  ('low', 1),
#  ('ora', 1),
#  ('hi', 1),
#  ('reaching', 1),
#  ('obtained', 1),
#  ('consumers', 1),
#  ('unfortunately', 1),
#  ('member', 1),
#  ('deletion', 1),
#  ('foreigner', 1),
#  ('im', 1),
#  ('sir', 1),
#  ('yous', 1),
#  ('missing', 1),
#  ('deleting', 1),
#  ...]
